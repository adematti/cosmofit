# %% [markdown]
# # Full shape examples
#
# In this notebook we will show how to perform full shape fits to data power spectrum, using Taylor expansion to speed likelihood evaluation.
# Look first at notebooks basic_examples.ipynb to get a flavor of *cosmofit* behaviour, and bao_examples.ipynb for application to BAO fits.

# %% [markdown]
# ## Fake power spectrum data

# %%
import numpy as np

from cosmoprimo.fiducial import DESI

cosmo = DESI()
edges = np.linspace(0., 0.3, 31)
k = (edges[:-1] + edges[1:]) / 2.
nmodes = 4. * np.pi / 3. * (edges[1:]**3 - edges[:-1]**3)
z = 1.
pk = cosmo.get_fourier().pk_interpolator()(k, z=z)
b = 2.
f = cosmo.growth_rate(z)
shotnoise = 1 / 1e-4
volume = 1e9

ells = (0, 2, 4)
poles = []
poles.append((b**2 + 2. / 3. * f * b + 1. / 5. * f**2) * pk + shotnoise)
poles.append((4. / 3. * f * b + 4. / 7. * f**2) * pk)
poles.append(8. / 35 * f**2 * pk)
poles = np.array(poles, dtype='f8')

from pypower import PowerSpectrumStatistics
mean = PowerSpectrumStatistics(edges, k, poles, nmodes=nmodes, ells=ells, shotnoise_nonorm=shotnoise, statistic='multipole')
cov = [2. * (2. * np.pi)**3 / (2 * ell + 1) / (volume * nmodes) * poles[0]**2 for ell in ells]
cov = np.diag(np.concatenate(cov, axis=0))

rng = np.random.RandomState(seed=42)
mocks = []
for i in range(1000):
    tmp = mean.deepcopy()
    tmp.power_nonorm.flat[...] = rng.multivariate_normal(mean.power_nonorm.ravel(), cov)
    mocks.append(tmp)

# %% [markdown]
# ## ShapeFit Likelihood

# %%
config = {}
config['like'] = {'class': 'cosmofit.likelihoods.PowerSpectrumMultipolesLikelihood',
                  'init': {'data': mocks, 'covariance': mocks, 'covariance_scale': True,
                           'klim': {0: [0.02, 0.2], 2: [0.02, 0.2]},  # fit monopole and quadrupole, between 0.02 and 0.2 h/Mpc
                           'zeff': z, 'fiducial': 'DESI'}}
# Here we use Kaiser power spectrum for fast calculation,
#  but there is also LPTTracerPowerSpectrumMultipoles based on Velocileptors
config['tracer'] = {'class': 'cosmofit.theories.full_shape.KaiserTracerPowerSpectrumMultipoles',
                    'params': {'b1': {'ref': {'dist': 'uniform', 'limits': [1.95, 2.05]}}},
                               'sn0': {'ref': {'dist': 'uniform', 'limits': [-50., 50.]}}}
                   # 'init': {'mu': 50}}  # only 50 mu (instead of 200) to speed up calculation in this notebook
config['param'] = {'class': 'cosmofit.theories.power_template.ShapeFitPowerSpectrumParameterization',
                    'params': {'dm': {'ref': {'dist': 'uniform', 'limits': [-0.01, 0.01]}},
                               'f': {'ref': {'dist': 'uniform', 'limits': [0.85, 0.88]}}},
                               'qp*r': {'ref': {'dist': 'uniform', 'limits': [0.99, 1.01]}}}
config['cosmo'] = {'class': 'cosmofit.theories.primordial_cosmology.Cosmoprimo'}

# NOTE: if we wanted to fit xi instead:
# config['like'] = {'class': 'cosmofit.likelihoods.CorrelationFunctionMultipolesLikelihood',
#                   'init': {'data': data, 'covariance': mocks,
#                            'slim': {0: [40., 160], 2: [40., 160]},  # fit monopole and quadrupole, between 40 and 160 Mpc/h
#                            'zeff': z, 'fiducial': 'DESI'}}
# config['tracer'] = {'class': 'cosmofit.theories.full_shape.KaiserTracerCorrelationFunctionMultipoles'}
# The rest would be the same

from cosmofit import LikelihoodPipeline, setup_logging

setup_logging()

likelihood = LikelihoodPipeline(config)
# Out:
# [000000.50] [0/1] 08-11 13:53  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/likelihoods/power_spectrum.yaml
# [000000.56] [0/1] 08-11 13:53  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/full_shape.yaml
# [000000.58] [0/1] 08-11 13:53  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000000.63] [0/1] 08-11 13:53  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/primordial_cosmology.yaml
# [000000.95] [0/1] 08-11 13:53  PowerSpectrumMultipolesLikelihood INFO     Covariance matrix with 36 points built from 1000 observations.
# [000000.95] [0/1] 08-11 13:53  PowerSpectrumMultipolesLikelihood INFO     ...resulting in Hartlap factor of 0.9630.
# [000000.95] [0/1] 08-11 13:53  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000000.97] [0/1] 08-11 13:53  PipelineConfig            INFO     No config for WindowedPowerSpectrumMultipoles found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000000.99] [0/1] 08-11 13:53  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000001.06] [0/1] 08-11 13:53  PipelineConfig            INFO     No config for ShapeFitPowerSpectrumTemplate found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000001.59] [0/1] 08-11 13:53  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000001.63] [0/1] 08-11 13:53  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000001.66] [0/1] 08-11 13:53  LikelihoodPipeline        INFO     Found calculators [PowerSpectrumMultipolesLikelihood(like), WindowedPowerSpectrumMultipoles(theory), KaiserTracerPowerSpectrumMultipoles(tracer), ShapeFitPowerSpectrumParameterization(param), ShapeFitPowerSpectrumTemplate(template), Cosmoprimo(cosmo), BasePowerSpectrumWiggles(wiggles), EffectAP(effectap)].
# [000001.66] [0/1] 08-11 13:53  LikelihoodPipeline        INFO     Found end calculators [PowerSpectrumMultipolesLikelihood(like)].
# [000002.88] [0/1] 08-11 13:53  LikelihoodPipeline        INFO     Found likelihood like.

# %%
from cosmofit.base import BasePipeline
from cosmofit.emulators import TaylorEmulatorEngine

pipeline = likelihood.select('tracer', type=BasePipeline)
emulator = TaylorEmulatorEngine(pipeline, order={'*': 2, 'sn0': 1})  # order 2 except for sn0 (order 1 is enough)
emulator.set_samples()
emulator.fit()
emulator.check()
emulator.plot(name='power')

import os
base_dir = '_tests'
kaiser_emulator_fn = os.path.join(base_dir, 'kaiser_emulator.npy')
emulator.save(kaiser_emulator_fn)
# Out:
# [000003.12] [0/1] 08-11 13:53  BasePipeline              WARNING  Derived parameter zeff of ShapeFitPowerSpectrumTemplate(template) is already derived in KaiserTracerPowerSpectrumMultipoles(tracer).
# [000003.13] [0/1] 08-11 13:53  TaylorEmulatorEngine      INFO     Varied parameters: ['sn0', 'b1', 'f', 'dm', 'qpar', 'qper'].
# [000003.13] [0/1] 08-11 13:53  TaylorEmulatorEngine      INFO     Found varying {'DV_over_rd', 'DH_over_DM', 'f_sqrt_A_p', 'DM_over_rd', 'DH_over_rd', 'm', 'power'} and fixed ['A_p', 'n', 'zeff', 'k', 'ells', 'fiducial'] outputs.
# [000005.34] [0/1] 08-11 13:53  TaylorEmulatorEngine      INFO     Diagnostics:
# [000005.67] [0/1] 08-11 13:53  TaylorEmulatorEngine      INFO     - mse of DV_over_rd is 1.64e-23 (square root = 4.05e-12).
# [000005.67] [0/1] 08-11 13:53  TaylorEmulatorEngine      INFO     - mse of DH_over_DM is 2.94e-24 (square root = 1.71e-12).
# [000005.67] [0/1] 08-11 13:53  TaylorEmulatorEngine      INFO     - mse of f_sqrt_A_p is 0 (square root = 0).
# [000005.67] [0/1] 08-11 13:53  TaylorEmulatorEngine      INFO     - mse of DM_over_rd is 2.31e-30 (square root = 1.52e-15).
# [000005.68] [0/1] 08-11 13:53  TaylorEmulatorEngine      INFO     - mse of DH_over_rd is 2.31e-30 (square root = 1.52e-15).
# [000005.68] [0/1] 08-11 13:53  TaylorEmulatorEngine      INFO     - mse of m is 0 (square root = 0).
# [000005.68] [0/1] 08-11 13:53  TaylorEmulatorEngine      INFO     - mse of power is 4.01e-15 (square root = 6.33e-08).
# [000006.18] [0/1] 08-11 13:53  TaylorEmulatorEngine      INFO     Saving _tests/kaiser_emulator.npy.
# [000006.18] [0/1] 08-11 13:53  TaylorEmulatorEngine      INFO     Saving _tests/kaiser_emulator.yaml.

# %% [markdown]
# ## Sampling
# Let us draw MC samples of the likelihood (actually posterior, including parameter priors).

# %%
from cosmofit.samplers import EmceeSampler

config['tracer']['load'] = kaiser_emulator_fn
del config['param'], config['cosmo']
likelihood = LikelihoodPipeline(config)

sampler = EmceeSampler(likelihood, seed=42)
converged = False
while not converged:
    sampler.run(niterations=500)
    converged = sampler.check(eigen_gr_stop=0.1)
# Out:
# [000006.82] [0/1] 08-11 13:53  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/likelihoods/power_spectrum.yaml
# [000006.82] [0/1] 08-11 13:53  KaiserTracerPowerSpectrumMultipoles INFO     Loading _tests/kaiser_emulator.npy.
# [000006.85] [0/1] 08-11 13:53  PipelineConfig            INFO     Loading config file _tests/kaiser_emulator.yaml
# [000007.20] [0/1] 08-11 13:53  PowerSpectrumMultipolesLikelihood INFO     Covariance matrix with 36 points built from 1000 observations.
# [000007.20] [0/1] 08-11 13:53  PowerSpectrumMultipolesLikelihood INFO     ...resulting in Hartlap factor of 0.9630.
# [000007.20] [0/1] 08-11 13:53  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000007.21] [0/1] 08-11 13:53  PipelineConfig            INFO     No config for WindowedPowerSpectrumMultipoles found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000007.28] [0/1] 08-11 13:53  LikelihoodPipeline        INFO     Found calculators [PowerSpectrumMultipolesLikelihood(like), WindowedPowerSpectrumMultipoles(theory), KaiserTracerPowerSpectrumMultipoles(tracer)].
# [000007.28] [0/1] 08-11 13:53  LikelihoodPipeline        INFO     Found end calculators [PowerSpectrumMultipolesLikelihood(like)].
# [000007.29] [0/1] 08-11 13:53  LikelihoodPipeline        INFO     Found likelihood like.
# [000007.36] [0/1] 08-11 13:53  EmceeSampler              INFO     Varied parameters: ['sn0', 'f', 'dm', 'qpar', 'qper', 'b1'].
# [000036.59] [0/1] 08-11 13:53  EmceeSampler              INFO     Diagnostics:
# [000036.63] [0/1] 08-11 13:53  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 4.97 > 0.1.
# [000036.68] [0/1] 08-11 13:53  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.657.
# [000036.74] [0/1] 08-11 13:53  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.892.
# [000036.76] [0/1] 08-11 13:53  EmceeSampler              INFO     - max Geweke is 0.914.
# [000036.87] [0/1] 08-11 13:53  EmceeSampler              INFO     - max integrated autocorrelation time is 34.8.
# [000065.35] [0/1] 08-11 13:54  EmceeSampler              INFO     Diagnostics:
# [000065.40] [0/1] 08-11 13:54  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 1.87 > 0.1.
# [000065.49] [0/1] 08-11 13:54  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 1.15.
# [000065.58] [0/1] 08-11 13:54  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 2.1.
# [000065.60] [0/1] 08-11 13:54  EmceeSampler              INFO     - max Geweke is 1.23.
# [000065.68] [0/1] 08-11 13:54  EmceeSampler              INFO     - max integrated autocorrelation time is 45.8.
# [000065.68] [0/1] 08-11 13:54  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.329.
# [000095.70] [0/1] 08-11 13:54  EmceeSampler              INFO     Diagnostics:
# [000095.77] [0/1] 08-11 13:54  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 1.4 > 0.1.
# [000095.88] [0/1] 08-11 13:54  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.755.
# [000096.00] [0/1] 08-11 13:54  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 1.24.
# [000096.02] [0/1] 08-11 13:54  EmceeSampler              INFO     - max Geweke is 0.687.
# [000096.19] [0/1] 08-11 13:54  EmceeSampler              INFO     - max integrated autocorrelation time is 61.5.
# [000096.19] [0/1] 08-11 13:54  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.255.
# [000123.78] [0/1] 08-11 13:55  EmceeSampler              INFO     Diagnostics:
# [000123.83] [0/1] 08-11 13:55  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.521 > 0.1.
# [000123.92] [0/1] 08-11 13:55  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.277.
# [000124.00] [0/1] 08-11 13:55  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.375.
# [000124.02] [0/1] 08-11 13:55  EmceeSampler              INFO     - max Geweke is 2.14.
# [000124.11] [0/1] 08-11 13:55  EmceeSampler              INFO     - max integrated autocorrelation time is 73.9.
# [000124.11] [0/1] 08-11 13:55  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.169.
# [000151.54] [0/1] 08-11 13:55  EmceeSampler              INFO     Diagnostics:
# [000151.59] [0/1] 08-11 13:55  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.194 > 0.1.
# [000151.69] [0/1] 08-11 13:55  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.147.
# [000151.79] [0/1] 08-11 13:55  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.116.
# [000151.81] [0/1] 08-11 13:55  EmceeSampler              INFO     - max Geweke is 1.88.
# [000151.89] [0/1] 08-11 13:55  EmceeSampler              INFO     - max integrated autocorrelation time is 87.1.
# [000151.89] [0/1] 08-11 13:55  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.152.
# [000180.45] [0/1] 08-11 13:56  EmceeSampler              INFO     Diagnostics:
# [000180.51] [0/1] 08-11 13:56  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.491 > 0.1.
# [000180.61] [0/1] 08-11 13:56  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.287.
# [000180.71] [0/1] 08-11 13:56  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.148.
# [000180.73] [0/1] 08-11 13:56  EmceeSampler              INFO     - max Geweke is 1.27.
# [000180.84] [0/1] 08-11 13:56  EmceeSampler              INFO     - max integrated autocorrelation time is 96.2.
# [000180.84] [0/1] 08-11 13:56  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0941.
# [000211.46] [0/1] 08-11 13:56  EmceeSampler              INFO     Diagnostics:
# [000211.56] [0/1] 08-11 13:56  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.395 > 0.1.
# [000211.66] [0/1] 08-11 13:56  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.225.
# [000211.84] [0/1] 08-11 13:56  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.135.
# [000211.89] [0/1] 08-11 13:56  EmceeSampler              INFO     - max Geweke is 0.466.
# [000212.16] [0/1] 08-11 13:56  EmceeSampler              INFO     - max integrated autocorrelation time is 95.3.
# [000212.17] [0/1] 08-11 13:56  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0913.
# [000240.84] [0/1] 08-11 13:57  EmceeSampler              INFO     Diagnostics:
# [000240.89] [0/1] 08-11 13:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.326 > 0.1.
# [000241.00] [0/1] 08-11 13:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.166.
# [000241.13] [0/1] 08-11 13:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0772.
# [000241.15] [0/1] 08-11 13:57  EmceeSampler              INFO     - max Geweke is 0.383.
# [000241.26] [0/1] 08-11 13:57  EmceeSampler              INFO     - max integrated autocorrelation time is 94.2.
# [000241.26] [0/1] 08-11 13:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0744.
# [000268.00] [0/1] 08-11 13:57  EmceeSampler              INFO     Diagnostics:
# [000268.09] [0/1] 08-11 13:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.274 > 0.1.
# [000268.19] [0/1] 08-11 13:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.137.
# [000268.32] [0/1] 08-11 13:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.078.
# [000268.33] [0/1] 08-11 13:57  EmceeSampler              INFO     - max Geweke is 0.302.
# [000268.44] [0/1] 08-11 13:57  EmceeSampler              INFO     - max integrated autocorrelation time is 94.
# [000268.44] [0/1] 08-11 13:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0288.
# [000295.03] [0/1] 08-11 13:58  EmceeSampler              INFO     Diagnostics:
# [000295.08] [0/1] 08-11 13:58  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.233 > 0.1.
# [000295.18] [0/1] 08-11 13:58  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.108.
# [000295.31] [0/1] 08-11 13:58  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0615.
# [000295.33] [0/1] 08-11 13:58  EmceeSampler              INFO     - max Geweke is 0.194.
# [000295.46] [0/1] 08-11 13:58  EmceeSampler              INFO     - max integrated autocorrelation time is 92.8.
# [000295.47] [0/1] 08-11 13:58  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0463.
# [000322.33] [0/1] 08-11 13:58  EmceeSampler              INFO     Diagnostics:
# [000322.38] [0/1] 08-11 13:58  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.204 > 0.1.
# [000322.43] [0/1] 08-11 13:58  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0936.
# [000322.55] [0/1] 08-11 13:58  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.07.
# [000322.56] [0/1] 08-11 13:58  EmceeSampler              INFO     - max Geweke is 0.212.
# [000322.66] [0/1] 08-11 13:58  EmceeSampler              INFO     - max integrated autocorrelation time is 93.5.
# [000322.66] [0/1] 08-11 13:58  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.046.
# [000349.24] [0/1] 08-11 13:59  EmceeSampler              INFO     Diagnostics:
# [000349.29] [0/1] 08-11 13:59  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.187 > 0.1.
# [000349.39] [0/1] 08-11 13:59  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0815.
# [000349.53] [0/1] 08-11 13:59  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0456.
# [000349.55] [0/1] 08-11 13:59  EmceeSampler              INFO     - max Geweke is 0.327.
# [000349.68] [0/1] 08-11 13:59  EmceeSampler              INFO     - max integrated autocorrelation time is 91.4.
# [000349.68] [0/1] 08-11 13:59  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0267.
# [000376.46] [0/1] 08-11 13:59  EmceeSampler              INFO     Diagnostics:
# [000376.51] [0/1] 08-11 13:59  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.17 > 0.1.
# [000376.61] [0/1] 08-11 13:59  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0727.
# [000376.78] [0/1] 08-11 13:59  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0522.
# [000376.79] [0/1] 08-11 13:59  EmceeSampler              INFO     - max Geweke is 0.205.
# [000376.92] [0/1] 08-11 13:59  EmceeSampler              INFO     - max integrated autocorrelation time is 91.8.
# [000376.92] [0/1] 08-11 13:59  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0714.
# [000403.39] [0/1] 08-11 14:00  EmceeSampler              INFO     Diagnostics:
# [000403.44] [0/1] 08-11 14:00  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.16 > 0.1.
# [000403.49] [0/1] 08-11 14:00  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0675.
# [000403.63] [0/1] 08-11 14:00  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0432.
# [000403.65] [0/1] 08-11 14:00  EmceeSampler              INFO     - max Geweke is 0.197.
# [000403.78] [0/1] 08-11 14:00  EmceeSampler              INFO     - max integrated autocorrelation time is 91.6 (reliable).
# [000403.78] [0/1] 08-11 14:00  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0414.
# [000430.21] [0/1] 08-11 14:00  EmceeSampler              INFO     Diagnostics:
# [000430.26] [0/1] 08-11 14:00  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.137 > 0.1.
# [000430.31] [0/1] 08-11 14:00  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.06.
# [000430.45] [0/1] 08-11 14:00  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0418.
# [000430.47] [0/1] 08-11 14:00  EmceeSampler              INFO     - max Geweke is 0.294.
# [000430.60] [0/1] 08-11 14:00  EmceeSampler              INFO     - max integrated autocorrelation time is 95.8 (reliable).
# [000430.60] [0/1] 08-11 14:00  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0444.
# [000457.02] [0/1] 08-11 14:00  EmceeSampler              INFO     Diagnostics:
# [000457.07] [0/1] 08-11 14:00  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.132 > 0.1.
# [000457.12] [0/1] 08-11 14:01  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0601.
# [000457.27] [0/1] 08-11 14:01  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0367.
# [000457.29] [0/1] 08-11 14:01  EmceeSampler              INFO     - max Geweke is 0.343.
# [000457.42] [0/1] 08-11 14:01  EmceeSampler              INFO     - max integrated autocorrelation time is 95.1 (reliable).
# [000457.42] [0/1] 08-11 14:01  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0176.
# [000483.77] [0/1] 08-11 14:01  EmceeSampler              INFO     Diagnostics:
# [000483.83] [0/1] 08-11 14:01  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.117 > 0.1.
# [000483.88] [0/1] 08-11 14:01  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0553.
# [000484.04] [0/1] 08-11 14:01  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0218.
# [000484.07] [0/1] 08-11 14:01  EmceeSampler              INFO     - max Geweke is 0.44.
# [000484.23] [0/1] 08-11 14:01  EmceeSampler              INFO     - max integrated autocorrelation time is 93 (reliable).
# [000484.23] [0/1] 08-11 14:01  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0564.
# [000510.78] [0/1] 08-11 14:01  EmceeSampler              INFO     Diagnostics:
# [000510.85] [0/1] 08-11 14:01  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.108 > 0.1.
# [000510.95] [0/1] 08-11 14:01  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0465.
# [000511.14] [0/1] 08-11 14:01  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0165.
# [000511.16] [0/1] 08-11 14:01  EmceeSampler              INFO     - max Geweke is 0.511.
# [000511.29] [0/1] 08-11 14:01  EmceeSampler              INFO     - max integrated autocorrelation time is 89.1 (reliable).
# [000511.30] [0/1] 08-11 14:01  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.043.
# [000538.54] [0/1] 08-11 14:02  EmceeSampler              INFO     Diagnostics:
# [000538.60] [0/1] 08-11 14:02  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.104 > 0.1.
# [000538.71] [0/1] 08-11 14:02  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0452.
# [000538.91] [0/1] 08-11 14:02  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0204.
# [000538.93] [0/1] 08-11 14:02  EmceeSampler              INFO     - max Geweke is 0.56.
# [000539.06] [0/1] 08-11 14:02  EmceeSampler              INFO     - max integrated autocorrelation time is 89.3 (reliable).
# [000539.06] [0/1] 08-11 14:02  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0467.
# [000567.58] [0/1] 08-11 14:02  EmceeSampler              INFO     Diagnostics:
# [000567.64] [0/1] 08-11 14:02  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0956 < 0.1.
# [000567.76] [0/1] 08-11 14:02  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0423.
# [000567.97] [0/1] 08-11 14:02  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0135.
# [000567.98] [0/1] 08-11 14:02  EmceeSampler              INFO     - max Geweke is 0.553.
# [000568.13] [0/1] 08-11 14:02  EmceeSampler              INFO     - max integrated autocorrelation time is 85.9 (reliable).
# [000568.13] [0/1] 08-11 14:02  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.039.
# [000594.45] [0/1] 08-11 14:03  EmceeSampler              INFO     Diagnostics:
# [000594.50] [0/1] 08-11 14:03  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0883 < 0.1.
# [000594.61] [0/1] 08-11 14:03  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0392.
# [000594.82] [0/1] 08-11 14:03  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0215.
# [000594.83] [0/1] 08-11 14:03  EmceeSampler              INFO     - max Geweke is 0.638.
# [000594.97] [0/1] 08-11 14:03  EmceeSampler              INFO     - max integrated autocorrelation time is 85.8 (reliable).
# [000594.97] [0/1] 08-11 14:03  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0306.

# %%
likelihood.end_calculators[0].plot()
# Out:
# array([<AxesSubplot:ylabel='$k P_{\\ell}(k)$ [$(\\mathrm{Mpc}/h)^{2}$]'>,
#        <AxesSubplot:ylabel='$\\Delta P_{0} / \\sigma_{ P_{0} }$'>,
#        <AxesSubplot:xlabel='$k$ [$h/\\mathrm{Mpc}$]', ylabel='$\\Delta P_{2} / \\sigma_{ P_{2} }$'>],
#       dtype=object)

# %%
chain = sampler.chains[0].remove_burnin(0.5)
print(chain.to_stats(tablefmt='pretty'))
# For some reason, b1 is a bit biased (maybe integration accuracy?)
# Out:
# +------+---------+---------+---------+---------+-------------------+-------------------+
# |      | argmax  |  mean   | median  |   std   |  quantile:1sigma  |  interval:1sigma  |
# +------+---------+---------+---------+---------+-------------------+-------------------+
# | sn0  |   -7    |   -9    |   -7    |   31    |     -4.3/+8.0     |     -3.9/+8.2     |
# |  f   | 0.86641 | 0.86645 | 0.86645 | 0.00092 |  -8.6e-4/+8.7e-4  |  -9.0e-4/+8.4e-4  |
# |  dm  | -0.0025 | -0.0023 | -0.0023 | 0.0011  | -0.00104/+0.00098 | -0.00105/+0.00097 |
# | qpar | 1.00048 | 1.00036 | 1.00036 | 0.00072 |  -5.1e-4/+5.1e-4  |  -5.3e-4/+4.9e-4  |
# | qper | 1.0018  | 1.0018  | 1.0017  | 0.0016  | -0.00105/+0.00086 | -0.00110/+0.00079 |
# |  b1  | 1.9777  | 1.9776  | 1.9776  | 0.0022  |  -0.0016/+0.0015  |  -0.0016/+0.0015  |
# +------+---------+---------+---------+---------+-------------------+-------------------+

# %%
from cosmofit.samples import plotting
plotting.plot_triangle(chain)
# Out:
# [000595.86] [0/1] 08-11 14:03  numexpr.utils             INFO     NumExpr defaulting to 8 threads.
# Removed no burn in
# [000596.17] [0/1] 08-11 14:03  root                      WARNING  fine_bins not large enough to well sample smoothing scale - sn0
# [000596.31] [0/1] 08-11 14:03  root                      WARNING  fine_bins not large enough to well sample smoothing scale - f
# [000596.63] [0/1] 08-11 14:03  root                      WARNING  fine_bins not large enough to well sample smoothing scale - qpar
# [000596.72] [0/1] 08-11 14:03  root                      WARNING  fine_bins not large enough to well sample smoothing scale - qper
# [000596.78] [0/1] 08-11 14:03  root                      WARNING  fine_bins not large enough to well sample smoothing scale - b1
# [000596.86] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, f
# [000597.09] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, qpar
# [000597.21] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, qper
# [000597.32] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, b1
# [000597.68] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: f, qpar
# [000597.80] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: f, qper
# [000597.94] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: f, b1
# [000598.07] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: dm, qpar
# [000598.21] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: dm, qper
# [000598.35] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: dm, b1
# [000598.47] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: qpar, qper
# [000598.60] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: qpar, b1
# [000598.72] [0/1] 08-11 14:03  root                      WARNING  fine_bins_2D not large enough for optimal density: qper, b1
# [000598.92] [0/1] 08-11 14:03  matplotlib.mathtext       INFO     Substituting symbol \perp from STIXGeneral
# [000598.93] [0/1] 08-11 14:03  matplotlib.mathtext       INFO     Substituting symbol \perp from STIXGeneral
# [000601.10] [0/1] 08-11 14:03  matplotlib.mathtext       INFO     Substituting symbol \perp from STIXGeneral
# [000601.10] [0/1] 08-11 14:03  matplotlib.mathtext       INFO     Substituting symbol \perp from STIXGeneral

# %% [markdown]
# ## Post-processing

# %%
fs_chain = sampler.chains[0]

# %%
import os
base_dir = '_tests'
like_emulator_fn = os.path.join(base_dir, 'like_emulator.npy')

config = {}
config['like'] = {'class': 'cosmofit.likelihoods.ShapeFitParameterizationLikelihood',
                  'init': {'chains': fs_chain, 'burnin': 0.5},
                  'emulator': {'save': like_emulator_fn}}
# Something goes wrong with h and Omega_m right now...
config['cosmo'] = {'class': 'cosmofit.theories.primordial_cosmology.Cosmoprimo',
                   'init': {'fiducial': 'DESI'},
                   'params': {'.delete': 'omega_cdm',
                              'Omega_m': {'fixed': False, 'prior': {'dist': 'uniform', 'limits': [0.05, 0.6]},
                                          'ref': {'dist': 'uniform', 'limits': [0.2, 0.4]}, 'latex': '\Omega_{m}'},
                               'A_s': {'fixed': False,
                                       'prior': {'dist': 'uniform', 'limits': [1.8e-9, 3e-9]},
                                       'ref': {'dist': 'uniform', 'limits': [1.9e-9, 2.1e-9]}},
                               'h': {'fixed': False,
                                     'prior': {'dist': 'uniform', 'limits': [0.4, 0.9]},
                                     'ref': {'dist': 'uniform', 'limits': [0.6, 0.8]}}}}

# %%
likelihood = LikelihoodPipeline(config)

from cosmofit.emulators import EmulatorConfig
config_emulator = EmulatorConfig({'class': 'TaylorEmulatorEngine', 'init': {'order': 2.}, 'sample': {'scale': 1e-2}, 'check': None})
config_emulator.run(likelihood.copy(type=BasePipeline))
# Out:
# [003781.26] [0/1] 08-11 14:56  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/primordial_cosmology.yaml
# [003781.31] [0/1] 08-11 14:56  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [003781.34] [0/1] 08-11 14:56  PipelineConfig            INFO     No config for BAOExtractor found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [003781.76] [0/1] 08-11 14:56  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [003781.80] [0/1] 08-11 14:56  PipelineConfig            INFO     No config for ShapeFitPowerSpectrumExtractor found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [003781.81] [0/1] 08-11 14:56  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [003781.86] [0/1] 08-11 14:56  LikelihoodPipeline        INFO     Found calculators [ShapeFitParameterizationLikelihood(like), BAOExtractor(bao), Cosmoprimo(cosmo), ShapeFitPowerSpectrumExtractor(shapefit), BasePowerSpectrumWiggles(wiggles)].
# [003781.86] [0/1] 08-11 14:56  LikelihoodPipeline        INFO     Found end calculators [ShapeFitParameterizationLikelihood(like)].
# [003781.86] [0/1] 08-11 14:56  ShapeFitParameterizationLikelihood INFO     Fitting input samples [Parameter(m, fixed), Parameter(f_sqrt_A_p, fixed), Parameter(DM_over_rd, fixed), Parameter(DH_over_rd, fixed)].
# [003782.72] [0/1] 08-11 14:56  LikelihoodPipeline        INFO     Found likelihood like.
# [003785.32] [0/1] 08-11 14:56  TaylorEmulatorEngine      INFO     Varied parameters: ['Omega_m', 'A_s', 'h'].
# [003785.32] [0/1] 08-11 14:56  TaylorEmulatorEngine      INFO     Found varying {'loglikelihood'} and fixed ['flatdata', 'covariance', 'precision'] outputs.
# [003811.27] [0/1] 08-11 14:56  TaylorEmulatorEngine      INFO     Diagnostics:
# [003811.29] [0/1] 08-11 14:56  TaylorEmulatorEngine      INFO     - mse of loglikelihood is 0.0107 (square root = 0.103).
# [003811.29] [0/1] 08-11 14:56  TaylorEmulatorEngine      INFO     Saving _tests/like_emulator.npy.
# [003811.30] [0/1] 08-11 14:56  TaylorEmulatorEngine      INFO     Saving _tests/like_emulator.yaml.

# %%
config['like']['load'] = like_emulator_fn
likelihood = LikelihoodPipeline(config)

from cosmofit.samplers import EmceeSampler

sampler = EmceeSampler(likelihood, seed=42)
converged = False
while not converged:
    sampler.run()
    converged = sampler.check(eigen_gr_stop=0.1)
# Out:
# [003818.60] [0/1] 08-11 14:57  ShapeFitParameterizationLikelihood INFO     Loading _tests/like_emulator.npy.
# [003818.61] [0/1] 08-11 14:57  PipelineConfig            INFO     Loading config file _tests/like_emulator.yaml
# [003818.63] [0/1] 08-11 14:57  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/primordial_cosmology.yaml
# [003819.06] [0/1] 08-11 14:57  LikelihoodPipeline        INFO     Found calculators [ShapeFitParameterizationLikelihood(like), Cosmoprimo(cosmo)].
# [003819.06] [0/1] 08-11 14:57  LikelihoodPipeline        INFO     Found end calculators [ShapeFitParameterizationLikelihood(like), Cosmoprimo(cosmo)].
# [003819.06] [0/1] 08-11 14:57  LikelihoodPipeline        INFO     Found likelihood like.
# [003819.09] [0/1] 08-11 14:57  EmceeSampler              INFO     Varied parameters: ['Omega_m', 'A_s', 'h'].
# [003821.08] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003821.09] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.53 > 0.1.
# [003821.11] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.174.
# [003821.14] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.504.
# [003821.14] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 0.438.
# [003821.16] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 17.1.
# [003823.01] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003823.02] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 1.64 > 0.1.
# [003823.04] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 1.2.
# [003823.07] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 2.25.
# [003823.07] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 0.631.
# [003823.09] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 24.5.
# [003823.09] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.301.
# [003824.89] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003824.90] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.547 > 0.1.
# [003824.91] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.451.
# [003824.94] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.814.
# [003824.95] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 0.979.
# [003824.97] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 28.6.
# [003824.97] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.165.
# [003826.90] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003826.91] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.466 > 0.1.
# [003826.93] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.369.
# [003826.96] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.626.
# [003826.97] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 1.04.
# [003826.98] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 33.
# [003826.99] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.131.
# [003828.90] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003828.92] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.135 > 0.1.
# [003828.93] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.12.
# [003828.97] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0124.
# [003828.98] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 0.84.
# [003829.00] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 35.1.
# [003829.00] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0622.
# [003830.80] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003830.82] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.228 > 0.1.
# [003830.83] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.191.
# [003830.86] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0532.
# [003830.87] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 1.2.
# [003830.90] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 39.3.
# [003830.90] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.107.
# [003832.73] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003832.75] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.176 > 0.1.
# [003832.77] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.148.
# [003832.81] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.043.
# [003832.81] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 0.482.
# [003832.85] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 39.8.
# [003832.85] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0273.
# [003834.66] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003834.68] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.153 > 0.1.
# [003834.69] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.128.
# [003834.73] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0323.
# [003834.74] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 0.266.
# [003834.75] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 40.1.
# [003834.75] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.033.
# [003836.65] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003836.66] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.141 > 0.1.
# [003836.68] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.118.
# [003836.72] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0274.
# [003836.72] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 0.219.
# [003836.75] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 40.2.
# [003836.75] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.017.
# [003838.61] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003838.62] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.118 > 0.1.
# [003838.64] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0991.
# [003838.68] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0176.
# [003838.68] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 0.467.
# [003838.71] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 40.7 (reliable).
# [003838.71] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.011.
# [003840.57] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003840.59] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.125 > 0.1.
# [003840.60] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.104.
# [003840.64] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0276.
# [003840.65] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 0.475.
# [003840.68] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 40.6 (reliable).
# [003840.68] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00793.
# [003842.61] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003842.63] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.112 > 0.1.
# [003842.64] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0937.
# [003842.68] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0303.
# [003842.69] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 0.186.
# [003842.71] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 40.4 (reliable).
# [003842.71] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0108.
# [003844.58] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003844.60] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0932 < 0.1.
# [003844.61] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0784.
# [003844.65] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0244.
# [003844.66] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 0.242.
# [003844.68] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 40.5 (reliable).
# [003844.68] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00323.
# [003846.50] [0/1] 08-11 14:57  EmceeSampler              INFO     Diagnostics:
# [003846.51] [0/1] 08-11 14:57  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0848 < 0.1.
# [003846.53] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0703.
# [003846.57] [0/1] 08-11 14:57  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0364.
# [003846.58] [0/1] 08-11 14:57  EmceeSampler              INFO     - max Geweke is 0.168.
# [003846.61] [0/1] 08-11 14:57  EmceeSampler              INFO     - max integrated autocorrelation time is 41.4 (reliable).
# [003846.61] [0/1] 08-11 14:57  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0218.

# %%
chain = sampler.chains[0].remove_burnin(0.5)
print(chain.to_stats(tablefmt='pretty'))
plotting.plot_triangle(chain, markers={'Omega_m': cosmo.Omega0_m, 'A_s': cosmo.A_s, 'h': cosmo.h})
# Out:
# +---------+----------+----------+----------+---------+-------------------+-------------------+
# |         |  argmax  |   mean   |  median  |   std   |  quantile:1sigma  |  interval:1sigma  |
# +---------+----------+----------+----------+---------+-------------------+-------------------+
# | Omega_m |  0.3152  |  0.3144  |  0.3152  | 0.0064  | -2.1e-4/+1.65e-3  | -1.2e-4/+1.73e-3  |
# |   A_s   | 2.044e-9 | 2.042e-9 | 2.044e-9 | 1.3e-11 | -7.1e-12/+9.1e-12 | -7.1e-12/+9.1e-12 |
# |    h    |  0.6732  |  0.6743  |  0.6732  | 0.0085  | -0.00246/+0.00051 | -0.00260/+0.00036 |
# +---------+----------+----------+----------+---------+-------------------+-------------------+
# Removed no burn in
# [004051.86] [0/1] 08-11 15:00  root                      WARNING  fine_bins not large enough to well sample smoothing scale - Omega_m
# [004051.92] [0/1] 08-11 15:00  root                      WARNING  auto bandwidth for A_s very small or failed (h=0.0007731395582804308,N_eff=16800.0). Using fallback (h=0.006415103649744555)
# [004051.99] [0/1] 08-11 15:00  root                      WARNING  auto bandwidth for h very small or failed (h=0.0008151957239961086,N_eff=16800.0). Using fallback (h=0.0014560915731298963)
# [004052.14] [0/1] 08-11 15:00  root                      WARNING  fine_bins_2D not large enough for optimal density: Omega_m, h
# [004052.24] [0/1] 08-11 15:00  root                      WARNING  fine_bins_2D not large enough for optimal density: A_s, h
