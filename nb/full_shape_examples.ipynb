# %% [markdown]
# # Full shape examples
#
# In this notebook we will show how to perform full shape fits to data power spectrum, using Taylor expansion to speed likelihood evaluation.
# Look first at notebooks basic_examples.ipynb to get a flavor of *cosmofit* behaviour, and bao_examples.ipynb for application to BAO fits.

# %% [markdown]
# ## Fake power spectrum data

# %%
import numpy as np

from cosmoprimo.fiducial import DESI

cosmo = DESI()
edges = np.linspace(0., 0.3, 31)
k = (edges[:-1] + edges[1:]) / 2.
nmodes = 4. * np.pi / 3. * (edges[1:]**3 - edges[:-1]**3)
z = 1.
pk = cosmo.get_fourier().pk_interpolator()(k, z=z)
b = 2.
f = cosmo.growth_rate(z)
shotnoise = 1 / 1e-4
volume = 1e9

ells = (0, 2, 4)
poles = []
poles.append((b**2 + 2. / 3. * f * b + 1. / 5. * f**2) * pk + shotnoise)
poles.append((4. / 3. * f * b + 4. / 7. * f**2) * pk)
poles.append(8. / 35 * f**2 * pk)
poles = np.array(poles, dtype='f8')

from pypower import PowerSpectrumStatistics
mean = PowerSpectrumStatistics(edges, k, poles, nmodes=nmodes, ells=ells, shotnoise_nonorm=shotnoise, statistic='multipole')
cov = [2. * (2. * np.pi)**3 / (2 * ell + 1) / (volume * nmodes) * poles[0]**2 for ell in ells]
cov = np.diag(np.concatenate(cov, axis=0))

rng = np.random.RandomState(seed=42)
mocks = []
for i in range(1000):
    tmp = mean.deepcopy()
    tmp.power_nonorm.flat[...] = rng.multivariate_normal(mean.power_nonorm.ravel(), cov)
    mocks.append(tmp)

# %% [markdown]
# ## ShapeFit Likelihood

# %%
config = {}
config['like'] = {'class': 'cosmofit.likelihoods.PowerSpectrumMultipolesLikelihood',
                  'init': {'data': mocks, 'covariance': mocks, 'covariance_scale': True,
                           'klim': {0: [0.02, 0.2], 2: [0.02, 0.2]},  # fit monopole and quadrupole, between 0.02 and 0.2 h/Mpc
                           'zeff': z, 'fiducial': 'DESI'}}
# Here we use Kaiser power spectrum for fast calculation,
#  but there is also LPTTracerPowerSpectrumMultipoles based on Velocileptors
config['tracer'] = {'class': 'cosmofit.theories.full_shape.KaiserTracerPowerSpectrumMultipoles',
                    'params': {'b1': {'ref': {'dist': 'uniform', 'limits': [1.95, 2.05]}}},
                               'sn0': {'ref': {'dist': 'uniform', 'limits': [-50., 50.]}}}
                   # 'init': {'mu': 50}}  # only 50 mu (instead of 200) to speed up calculation in this notebook
config['param'] = {'class': 'cosmofit.theories.power_template.ShapeFitPowerSpectrumParameterization',
                    'params': {'dm': {'ref': {'dist': 'uniform', 'limits': [-0.01, 0.01]}},
                               'f': {'ref': {'dist': 'uniform', 'limits': [0.85, 0.88]}}},
                                'qp*r': {'ref': {'dist': 'uniform', 'limits': [0.99, 1.01]}}}
config['cosmo'] = {'class': 'cosmofit.theories.primordial_cosmology.Cosmoprimo'}

# NOTE: if we wanted to fit xi instead:
# config['like'] = {'class': 'cosmofit.likelihoods.CorrelationFunctionMultipolesLikelihood',
#                   'init': {'data': data, 'covariance': mocks,
#                            'slim': {0: [40., 160], 2: [40., 160]},  # fit monopole and quadrupole, between 40 and 160 Mpc/h
#                            'zeff': z, 'fiducial': 'DESI'}}
# config['tracer'] = {'class': 'cosmofit.theories.full_shape.KaiserTracerCorrelationFunctionMultipoles'}
# The rest would be the same

from cosmofit import LikelihoodPipeline, setup_logging

setup_logging()

likelihood = LikelihoodPipeline(config)
# Out:
# [000000.53] [0/1] 07-31 18:13  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/likelihoods/power_spectrum.yaml
# [000000.60] [0/1] 07-31 18:13  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/full_shape.yaml
# [000000.63] [0/1] 07-31 18:13  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000000.67] [0/1] 07-31 18:13  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/primordial_cosmology.yaml
# [000000.99] [0/1] 07-31 18:13  PowerSpectrumMultipolesLikelihood INFO     Covariance matrix with 36 points built from 1000 observations.
# [000000.99] [0/1] 07-31 18:13  PowerSpectrumMultipolesLikelihood INFO     ...resulting in Hartlap factor of 0.9630.
# [000001.00] [0/1] 07-31 18:13  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000001.01] [0/1] 07-31 18:13  PipelineConfig            INFO     No config for WindowedPowerSpectrumMultipoles found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000001.04] [0/1] 07-31 18:13  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000001.12] [0/1] 07-31 18:13  PipelineConfig            INFO     No config for ShapeFitPowerSpectrumTemplate found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000001.57] [0/1] 07-31 18:13  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000001.61] [0/1] 07-31 18:13  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000001.64] [0/1] 07-31 18:13  LikelihoodPipeline        INFO     Found calculators [PowerSpectrumMultipolesLikelihood(like), WindowedPowerSpectrumMultipoles(theory), KaiserTracerPowerSpectrumMultipoles(tracer), ShapeFitPowerSpectrumParameterization(param), ShapeFitPowerSpectrumTemplate(template), Cosmoprimo(cosmo), BasePowerSpectrumWiggles(wiggles), EffectAP(effectap)].
# [000001.64] [0/1] 07-31 18:13  LikelihoodPipeline        INFO     Found end calculators [PowerSpectrumMultipolesLikelihood(like)].
# [000002.47] [0/1] 07-31 18:13  LikelihoodPipeline        INFO     Found likelihood like.

# %%
from cosmofit.base import BasePipeline
from cosmofit.emulators import TaylorEmulatorEngine

pipeline = likelihood.select('tracer', type=BasePipeline)
emulator = TaylorEmulatorEngine(pipeline, order={'*': 2, 'sn0': 1})  # order 2 except for sn0 (order 1 is enough)
emulator.set_samples()
emulator.fit()
emulator.check()
emulator.plot(name='power')

import os
base_dir = '_tests'
kaiser_emulator_fn = os.path.join(base_dir, 'kaiser_emulator.npy')
emulator.save(kaiser_emulator_fn)
# Out:
# [000002.62] [0/1] 07-31 18:13  BasePipeline              WARNING  Derived parameter zeff of ShapeFitPowerSpectrumTemplate(template) is already derived in KaiserTracerPowerSpectrumMultipoles(tracer)
# [000002.62] [0/1] 07-31 18:13  TaylorEmulatorEngine      INFO     Varied parameters: ['sn0', 'b1', 'f', 'dm', 'qpar', 'qper'].
# [000002.62] [0/1] 07-31 18:13  TaylorEmulatorEngine      INFO     Found varying {'DH_over_rd', 'DH_over_DM', 'm', 'DM_over_rd', 'DV_over_rd', 'f_sqrt_A_p', 'power'} and fixed ['A_p', 'n', 'zeff', 'k', 'ells', 'fiducial'] outputs.
# [000025.08] [0/1] 07-31 18:14  TaylorEmulatorEngine      INFO     Diagnostics:
# [000053.66] [0/1] 07-31 18:14  TaylorEmulatorEngine      INFO     - mse of DH_over_rd is 2.52e-29 (square root = 5.02e-15).
# [000053.66] [0/1] 07-31 18:14  TaylorEmulatorEngine      INFO     - mse of DH_over_DM is 1.49e-23 (square root = 3.86e-12).
# [000053.66] [0/1] 07-31 18:14  TaylorEmulatorEngine      INFO     - mse of m is 0 (square root = 0).
# [000053.66] [0/1] 07-31 18:14  TaylorEmulatorEngine      INFO     - mse of DM_over_rd is 2.52e-29 (square root = 5.02e-15).
# [000053.66] [0/1] 07-31 18:14  TaylorEmulatorEngine      INFO     - mse of DV_over_rd is 3e-23 (square root = 5.48e-12).
# [000053.66] [0/1] 07-31 18:14  TaylorEmulatorEngine      INFO     - mse of f_sqrt_A_p is 4.04e-28 (square root = 2.01e-14).
# [000053.66] [0/1] 07-31 18:14  TaylorEmulatorEngine      INFO     - mse of power is 1.53e-14 (square root = 1.24e-07).
# [000054.09] [0/1] 07-31 18:14  TaylorEmulatorEngine      INFO     Saving _tests/kaiser_emulator.npy.
# [000054.09] [0/1] 07-31 18:14  TaylorEmulatorEngine      INFO     Saving _tests/kaiser_emulator.yaml.

# %% [markdown]
# ## Sampling
# Let us draw MC samples of the likelihood (actually posterior, including parameter priors).

# %%
from cosmofit.samplers import EmceeSampler

config['tracer']['load'] = kaiser_emulator_fn
del config['param'], config['cosmo']
likelihood = LikelihoodPipeline(config)

sampler = EmceeSampler(likelihood, seed=42)
converged = False
while not converged:
    sampler.run(niterations=500)
    converged = sampler.check(eigen_gr_stop=0.1)
# Out:
# [000054.62] [0/1] 07-31 18:14  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/likelihoods/power_spectrum.yaml
# [000054.62] [0/1] 07-31 18:14  KaiserTracerPowerSpectrumMultipoles INFO     Loading _tests/kaiser_emulator.npy.
# [000054.65] [0/1] 07-31 18:14  PipelineConfig            INFO     Loading config file _tests/kaiser_emulator.yaml
# [000054.98] [0/1] 07-31 18:14  PowerSpectrumMultipolesLikelihood INFO     Covariance matrix with 36 points built from 1000 observations.
# [000054.98] [0/1] 07-31 18:14  PowerSpectrumMultipolesLikelihood INFO     ...resulting in Hartlap factor of 0.9630.
# [000054.99] [0/1] 07-31 18:14  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000054.99] [0/1] 07-31 18:14  PipelineConfig            INFO     No config for WindowedPowerSpectrumMultipoles found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000055.06] [0/1] 07-31 18:14  LikelihoodPipeline        INFO     Found calculators [PowerSpectrumMultipolesLikelihood(like), WindowedPowerSpectrumMultipoles(theory), KaiserTracerPowerSpectrumMultipoles(tracer)].
# [000055.06] [0/1] 07-31 18:14  LikelihoodPipeline        INFO     Found end calculators [PowerSpectrumMultipolesLikelihood(like)].
# [000055.07] [0/1] 07-31 18:14  LikelihoodPipeline        INFO     Found likelihood like.
# [000055.14] [0/1] 07-31 18:14  EmceeSampler              INFO     Varied parameters: ['sn0', 'f', 'dm', 'qpar', 'qper', 'b1'].
# [000083.45] [0/1] 07-31 18:15  EmceeSampler              INFO     Diagnostics:
# [000083.50] [0/1] 07-31 18:15  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 8.17 > 0.1.
# [000083.55] [0/1] 07-31 18:15  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 2.08.
# [000083.61] [0/1] 07-31 18:15  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 2.62.
# [000083.62] [0/1] 07-31 18:15  EmceeSampler              INFO     - max Geweke is 1.57.
# [000083.71] [0/1] 07-31 18:15  EmceeSampler              INFO     - max integrated autocorrelation time is 44.
# [000111.70] [0/1] 07-31 18:15  EmceeSampler              INFO     Diagnostics:
# [000111.75] [0/1] 07-31 18:15  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 2.6 > 0.1.
# [000111.79] [0/1] 07-31 18:15  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 1.37.
# [000111.86] [0/1] 07-31 18:15  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 2.21.
# [000111.88] [0/1] 07-31 18:15  EmceeSampler              INFO     - max Geweke is 2.05.
# [000111.96] [0/1] 07-31 18:15  EmceeSampler              INFO     - max integrated autocorrelation time is 48.5.
# [000111.96] [0/1] 07-31 18:15  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.304.
# [000139.73] [0/1] 07-31 18:15  EmceeSampler              INFO     Diagnostics:
# [000139.78] [0/1] 07-31 18:15  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 2.63 > 0.1.
# [000139.82] [0/1] 07-31 18:15  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 1.23.
# [000139.89] [0/1] 07-31 18:15  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 1.95.
# [000139.91] [0/1] 07-31 18:15  EmceeSampler              INFO     - max Geweke is 1.18.
# [000140.01] [0/1] 07-31 18:15  EmceeSampler              INFO     - max integrated autocorrelation time is 69.4.
# [000140.01] [0/1] 07-31 18:15  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.315.
# [000169.35] [0/1] 07-31 18:16  EmceeSampler              INFO     Diagnostics:
# [000169.41] [0/1] 07-31 18:16  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.526 > 0.1.
# [000169.51] [0/1] 07-31 18:16  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.332.
# [000169.59] [0/1] 07-31 18:16  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.9.
# [000169.61] [0/1] 07-31 18:16  EmceeSampler              INFO     - max Geweke is 3.61.
# [000169.70] [0/1] 07-31 18:16  EmceeSampler              INFO     - max integrated autocorrelation time is 90.7.
# [000169.70] [0/1] 07-31 18:16  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.235.
# [000199.20] [0/1] 07-31 18:16  EmceeSampler              INFO     Diagnostics:
# [000199.25] [0/1] 07-31 18:16  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.508 > 0.1.
# [000199.30] [0/1] 07-31 18:16  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.369.
# [000199.39] [0/1] 07-31 18:16  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.775.
# [000199.41] [0/1] 07-31 18:16  EmceeSampler              INFO     - max Geweke is 3.26.
# [000199.51] [0/1] 07-31 18:16  EmceeSampler              INFO     - max integrated autocorrelation time is 107.
# [000199.51] [0/1] 07-31 18:16  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.149.
# [000230.51] [0/1] 07-31 18:17  EmceeSampler              INFO     Diagnostics:
# [000230.57] [0/1] 07-31 18:17  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.961 > 0.1.
# [000230.67] [0/1] 07-31 18:17  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.464.
# [000230.84] [0/1] 07-31 18:17  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.967.
# [000230.87] [0/1] 07-31 18:17  EmceeSampler              INFO     - max Geweke is 1.22.
# [000231.09] [0/1] 07-31 18:17  EmceeSampler              INFO     - max integrated autocorrelation time is 112.
# [000231.09] [0/1] 07-31 18:17  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0707.
# [000261.57] [0/1] 07-31 18:18  EmceeSampler              INFO     Diagnostics:
# [000261.62] [0/1] 07-31 18:18  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.682 > 0.1.
# [000261.66] [0/1] 07-31 18:18  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.331.
# [000261.76] [0/1] 07-31 18:18  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.846.
# [000261.77] [0/1] 07-31 18:18  EmceeSampler              INFO     - max Geweke is 0.343.
# [000261.87] [0/1] 07-31 18:18  EmceeSampler              INFO     - max integrated autocorrelation time is 111.
# [000261.87] [0/1] 07-31 18:18  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0884.
# [000292.74] [0/1] 07-31 18:18  EmceeSampler              INFO     Diagnostics:
# [000292.80] [0/1] 07-31 18:18  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.49 > 0.1.
# [000292.85] [0/1] 07-31 18:18  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.237.
# [000292.94] [0/1] 07-31 18:18  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.533.
# [000292.96] [0/1] 07-31 18:18  EmceeSampler              INFO     - max Geweke is 0.502.
# [000293.06] [0/1] 07-31 18:18  EmceeSampler              INFO     - max integrated autocorrelation time is 114.
# [000293.06] [0/1] 07-31 18:18  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0678.
# [000322.33] [0/1] 07-31 18:19  EmceeSampler              INFO     Diagnostics:
# [000322.38] [0/1] 07-31 18:19  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.405 > 0.1.
# [000322.43] [0/1] 07-31 18:19  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.204.
# [000322.54] [0/1] 07-31 18:19  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.517.
# [000322.56] [0/1] 07-31 18:19  EmceeSampler              INFO     - max Geweke is 0.451.
# [000322.70] [0/1] 07-31 18:19  EmceeSampler              INFO     - max integrated autocorrelation time is 121.
# [000322.70] [0/1] 07-31 18:19  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0679.
# [000350.94] [0/1] 07-31 18:19  EmceeSampler              INFO     Diagnostics:
# [000351.01] [0/1] 07-31 18:19  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.344 > 0.1.
# [000351.11] [0/1] 07-31 18:19  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.173.
# [000351.22] [0/1] 07-31 18:19  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.25.
# [000351.24] [0/1] 07-31 18:19  EmceeSampler              INFO     - max Geweke is 0.452.
# [000351.35] [0/1] 07-31 18:19  EmceeSampler              INFO     - max integrated autocorrelation time is 120.
# [000351.35] [0/1] 07-31 18:19  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0458.
# [000379.97] [0/1] 07-31 18:19  EmceeSampler              INFO     Diagnostics:
# [000380.02] [0/1] 07-31 18:19  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.287 > 0.1.
# [000380.12] [0/1] 07-31 18:19  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.147.
# [000380.27] [0/1] 07-31 18:19  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.166.
# [000380.30] [0/1] 07-31 18:19  EmceeSampler              INFO     - max Geweke is 0.493.
# [000380.45] [0/1] 07-31 18:19  EmceeSampler              INFO     - max integrated autocorrelation time is 124.
# [000380.45] [0/1] 07-31 18:19  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0313.
# [000412.20] [0/1] 07-31 18:20  EmceeSampler              INFO     Diagnostics:
# [000412.28] [0/1] 07-31 18:20  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.248 > 0.1.
# [000412.34] [0/1] 07-31 18:20  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.123.
# [000412.47] [0/1] 07-31 18:20  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.116.
# [000412.48] [0/1] 07-31 18:20  EmceeSampler              INFO     - max Geweke is 0.549.
# [000412.61] [0/1] 07-31 18:20  EmceeSampler              INFO     - max integrated autocorrelation time is 125.
# [000412.61] [0/1] 07-31 18:20  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0269.
# [000441.18] [0/1] 07-31 18:21  EmceeSampler              INFO     Diagnostics:
# [000441.23] [0/1] 07-31 18:21  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.241 > 0.1.
# [000441.28] [0/1] 07-31 18:21  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.11.
# [000441.43] [0/1] 07-31 18:21  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0843.
# [000441.46] [0/1] 07-31 18:21  EmceeSampler              INFO     - max Geweke is 0.606.
# [000441.64] [0/1] 07-31 18:21  EmceeSampler              INFO     - max integrated autocorrelation time is 120.
# [000441.64] [0/1] 07-31 18:21  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0426.
# [000469.98] [0/1] 07-31 18:21  EmceeSampler              INFO     Diagnostics:
# [000470.04] [0/1] 07-31 18:21  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.213 > 0.1.
# [000470.09] [0/1] 07-31 18:21  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0946.
# [000470.24] [0/1] 07-31 18:21  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0747.
# [000470.25] [0/1] 07-31 18:21  EmceeSampler              INFO     - max Geweke is 0.687.
# [000470.39] [0/1] 07-31 18:21  EmceeSampler              INFO     - max integrated autocorrelation time is 121.
# [000470.39] [0/1] 07-31 18:21  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0269.
# [000498.45] [0/1] 07-31 18:21  EmceeSampler              INFO     Diagnostics:
# [000498.50] [0/1] 07-31 18:21  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.18 > 0.1.
# [000498.56] [0/1] 07-31 18:21  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0773.
# [000498.71] [0/1] 07-31 18:21  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0526.
# [000498.74] [0/1] 07-31 18:21  EmceeSampler              INFO     - max Geweke is 0.782.
# [000498.87] [0/1] 07-31 18:21  EmceeSampler              INFO     - max integrated autocorrelation time is 117.
# [000498.87] [0/1] 07-31 18:21  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.036.
# [000527.63] [0/1] 07-31 18:22  EmceeSampler              INFO     Diagnostics:
# [000527.70] [0/1] 07-31 18:22  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.156 > 0.1.
# [000527.79] [0/1] 07-31 18:22  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0637.
# [000527.97] [0/1] 07-31 18:22  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.049.
# [000527.98] [0/1] 07-31 18:22  EmceeSampler              INFO     - max Geweke is 0.853.
# [000528.14] [0/1] 07-31 18:22  EmceeSampler              INFO     - max integrated autocorrelation time is 115.
# [000528.14] [0/1] 07-31 18:22  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0345.
# [000558.89] [0/1] 07-31 18:22  EmceeSampler              INFO     Diagnostics:
# [000558.96] [0/1] 07-31 18:22  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.143 > 0.1.
# [000559.01] [0/1] 07-31 18:22  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0539.
# [000559.17] [0/1] 07-31 18:22  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0373.
# [000559.20] [0/1] 07-31 18:22  EmceeSampler              INFO     - max Geweke is 0.917.
# [000559.36] [0/1] 07-31 18:22  EmceeSampler              INFO     - max integrated autocorrelation time is 112 (reliable).
# [000559.37] [0/1] 07-31 18:22  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0288.
# [000589.69] [0/1] 07-31 18:23  EmceeSampler              INFO     Diagnostics:
# [000589.75] [0/1] 07-31 18:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.13 > 0.1.
# [000589.81] [0/1] 07-31 18:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0466.
# [000589.99] [0/1] 07-31 18:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0389.
# [000590.01] [0/1] 07-31 18:23  EmceeSampler              INFO     - max Geweke is 0.956.
# [000590.16] [0/1] 07-31 18:23  EmceeSampler              INFO     - max integrated autocorrelation time is 110 (reliable).
# [000590.16] [0/1] 07-31 18:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.03.
# [000621.07] [0/1] 07-31 18:24  EmceeSampler              INFO     Diagnostics:
# [000621.14] [0/1] 07-31 18:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.116 > 0.1.
# [000621.20] [0/1] 07-31 18:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0382.
# [000621.39] [0/1] 07-31 18:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0311.
# [000621.41] [0/1] 07-31 18:24  EmceeSampler              INFO     - max Geweke is 1.03.
# [000621.56] [0/1] 07-31 18:24  EmceeSampler              INFO     - max integrated autocorrelation time is 109 (reliable).
# [000621.56] [0/1] 07-31 18:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0253.
# [000651.51] [0/1] 07-31 18:24  EmceeSampler              INFO     Diagnostics:
# [000651.58] [0/1] 07-31 18:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.105 > 0.1.
# [000651.64] [0/1] 07-31 18:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.035.
# [000651.83] [0/1] 07-31 18:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0206.
# [000651.85] [0/1] 07-31 18:24  EmceeSampler              INFO     - max Geweke is 1.01.
# [000652.05] [0/1] 07-31 18:24  EmceeSampler              INFO     - max integrated autocorrelation time is 109 (reliable).
# [000652.05] [0/1] 07-31 18:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00857.
# [000682.40] [0/1] 07-31 18:25  EmceeSampler              INFO     Diagnostics:
# [000682.46] [0/1] 07-31 18:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0971 < 0.1.
# [000682.58] [0/1] 07-31 18:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0339.
# [000682.79] [0/1] 07-31 18:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0174.
# [000682.81] [0/1] 07-31 18:25  EmceeSampler              INFO     - max Geweke is 1.01.
# [000682.94] [0/1] 07-31 18:25  EmceeSampler              INFO     - max integrated autocorrelation time is 106 (reliable).
# [000682.94] [0/1] 07-31 18:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0296.
# [000712.44] [0/1] 07-31 18:25  EmceeSampler              INFO     Diagnostics:
# [000712.50] [0/1] 07-31 18:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0909 < 0.1.
# [000712.62] [0/1] 07-31 18:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0305.
# [000712.84] [0/1] 07-31 18:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0326.
# [000712.88] [0/1] 07-31 18:25  EmceeSampler              INFO     - max Geweke is 0.99.
# [000713.08] [0/1] 07-31 18:25  EmceeSampler              INFO     - max integrated autocorrelation time is 103 (reliable).
# [000713.08] [0/1] 07-31 18:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0354.

# %%
likelihood.end_calculators[0].plot()
# Out:
# array([<AxesSubplot:ylabel='$k P_{\\ell}(k)$ [$(\\mathrm{Mpc}/h)^{2}$]'>,
#        <AxesSubplot:ylabel='$\\Delta P_{0} / \\sigma_{ P_{0} }$'>,
#        <AxesSubplot:xlabel='$k$ [$h/\\mathrm{Mpc}$]', ylabel='$\\Delta P_{2} / \\sigma_{ P_{2} }$'>],
#       dtype=object)

# %%
chain = sampler.chains[0].remove_burnin(0.5)
print(chain.to_stats(tablefmt='pretty'))
# For some reason, b1 is a bit biased (maybe integration accuracy?)
# Out:
# +------+---------+---------+---------+---------+-------------------+-------------------+
# |      | argmax  |  mean   | median  |   std   |  quantile:1sigma  |  interval:1sigma  |
# +------+---------+---------+---------+---------+-------------------+-------------------+
# | sn0  |   -6    |   -9    |   -7    |   39    |     -4.2/+7.7     |     -3.7/+8.2     |
# |  f   | 0.8666  | 0.8663  | 0.8664  | 0.0011  |  -8.8e-4/+9.5e-4  | -7.8e-4/+1.04e-3  |
# |  dm  | -0.0025 | -0.0023 | -0.0023 | 0.0012  | -0.00106/+0.00098 | -0.00109/+0.00095 |
# | qpar | 1.00031 | 1.00033 | 1.00034 | 0.00089 |  -4.8e-4/+5.2e-4  |  -4.9e-4/+5.1e-4  |
# | qper | 1.0017  | 1.0016  | 1.0016  | 0.0014  |  -8.8e-4/+9.4e-4  | -8.0e-4/+1.01e-3  |
# |  b1  | 1.9776  | 1.9778  | 1.9777  | 0.0027  |  -0.0016/+0.0014  |  -0.0017/+0.0013  |
# +------+---------+---------+---------+---------+-------------------+-------------------+

# %%
from cosmofit.samples import plotting
plotting.plot_triangle(chain)
# Out:
# [000714.08] [0/1] 07-31 18:25  numexpr.utils             INFO     NumExpr defaulting to 8 threads.
# Removed no burn in
# [000714.42] [0/1] 07-31 18:25  root                      WARNING  fine_bins not large enough to well sample smoothing scale - sn0
# [000714.85] [0/1] 07-31 18:25  root                      WARNING  fine_bins not large enough to well sample smoothing scale - qper
# [000715.05] [0/1] 07-31 18:25  root                      WARNING  fine_bins not large enough to well sample smoothing scale - b1
# [000715.13] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, f
# [000715.35] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, qpar
# [000715.46] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, qper
# [000715.58] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, b1
# [000715.83] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: f, qpar
# [000715.95] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: f, qper
# [000716.08] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: f, b1
# [000716.20] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: dm, qpar
# [000716.33] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: dm, qper
# [000716.46] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: dm, b1
# [000716.57] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: qpar, qper
# [000716.69] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: qpar, b1
# [000716.80] [0/1] 07-31 18:25  root                      WARNING  fine_bins_2D not large enough for optimal density: qper, b1
# [000717.01] [0/1] 07-31 18:25  matplotlib.mathtext       INFO     Substituting symbol \perp from STIXGeneral
# [000717.02] [0/1] 07-31 18:25  matplotlib.mathtext       INFO     Substituting symbol \perp from STIXGeneral
# [000719.20] [0/1] 07-31 18:25  matplotlib.mathtext       INFO     Substituting symbol \perp from STIXGeneral
# [000719.20] [0/1] 07-31 18:25  matplotlib.mathtext       INFO     Substituting symbol \perp from STIXGeneral

# %% [markdown]
# ## Post-processing

# %%
fs_chain = sampler.chains[0]

# %%
import os
base_dir = '_tests'
like_emulator_fn = os.path.join(base_dir, 'like_emulator.npy')

config = {}
config['like'] = {'class': 'cosmofit.likelihoods.ShapeFitParameterizationLikelihood',
                  'init': {'chains': fs_chain, 'burnin': 0.5},
                  'emulator': {'save': like_emulator_fn}}
# Something goes wrong with h and Omega_m right now...
config['cosmo'] = {'class': 'cosmofit.theories.primordial_cosmology.Cosmoprimo',
                   'init': {'fiducial': 'DESI'},
                   'params': {'.delete': 'omega_cdm',
                              'Omega_m': {'fixed': True, 'prior': {'dist': 'uniform', 'limits': [0.05, 0.6]},
                                          'ref': {'dist': 'uniform', 'limits': [0.2, 0.4]}, 'latex': '\Omega_{m}'},
                               'A_s': {'fixed': False,
                                       'prior': {'dist': 'uniform', 'limits': [1.8e-9, 3e-9]},
                                       'ref': {'dist': 'uniform', 'limits': [1.9e-9, 2.1e-9]}},
                               'h': {'fixed': True,
                                     'prior': {'dist': 'uniform', 'limits': [0.4, 0.9]},
                                     'ref': {'dist': 'uniform', 'limits': [0.6, 0.8]}}}}

# %%
likelihood = LikelihoodPipeline(config)

from cosmofit.emulators import EmulatorConfig
config_emulator = EmulatorConfig({'class': 'TaylorEmulatorEngine', 'init': {'order': 3.}, 'sample': {'scale': 1e-2}, 'check': None})
config_emulator.run(likelihood.copy(type=BasePipeline))
# Out:
# [000719.77] [0/1] 07-31 18:25  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/primordial_cosmology.yaml
# [000719.84] [0/1] 07-31 18:25  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000719.87] [0/1] 07-31 18:25  PipelineConfig            INFO     No config for BAOExtractor found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000720.29] [0/1] 07-31 18:25  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000720.33] [0/1] 07-31 18:25  PipelineConfig            INFO     No config for ShapeFitPowerSpectrumExtractor found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000720.34] [0/1] 07-31 18:25  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000720.40] [0/1] 07-31 18:25  LikelihoodPipeline        INFO     Found calculators [ShapeFitParameterizationLikelihood(like), BAOExtractor(bao), Cosmoprimo(cosmo), ShapeFitPowerSpectrumExtractor(shapefit), BasePowerSpectrumWiggles(wiggles)].
# [000720.40] [0/1] 07-31 18:25  LikelihoodPipeline        INFO     Found end calculators [ShapeFitParameterizationLikelihood(like)].
# [000720.40] [0/1] 07-31 18:25  ShapeFitParameterizationLikelihood INFO     Fitting input samples [Parameter(m, fixed), Parameter(f_sqrt_A_p, fixed), Parameter(DM_over_rd, fixed), Parameter(DH_over_rd, fixed)].
# [000721.42] [0/1] 07-31 18:25  LikelihoodPipeline        INFO     Found likelihood like.
# [000723.78] [0/1] 07-31 18:25  TaylorEmulatorEngine      INFO     Varied parameters: ['A_s'].
# [000723.79] [0/1] 07-31 18:25  TaylorEmulatorEngine      INFO     Found varying {'loglikelihood'} and fixed ['flatdata', 'covariance', 'precision'] outputs.
# [000729.45] [0/1] 07-31 18:25  TaylorEmulatorEngine      INFO     Diagnostics:
# [000729.46] [0/1] 07-31 18:25  TaylorEmulatorEngine      INFO     - mse of loglikelihood is 2.43e-13 (square root = 4.93e-07).
# [000729.46] [0/1] 07-31 18:25  TaylorEmulatorEngine      INFO     Saving _tests/like_emulator.npy.
# [000729.46] [0/1] 07-31 18:25  TaylorEmulatorEngine      INFO     Saving _tests/like_emulator.yaml.

# %%
config['like']['load'] = like_emulator_fn
likelihood = LikelihoodPipeline(config)

from cosmofit.samplers import EmceeSampler

sampler = EmceeSampler(likelihood, seed=42)
converged = False
while not converged:
    sampler.run()
    converged = sampler.check(eigen_gr_stop=0.1)
# Out:
# [000729.48] [0/1] 07-31 18:25  ShapeFitParameterizationLikelihood INFO     Loading _tests/like_emulator.npy.
# [000729.50] [0/1] 07-31 18:25  PipelineConfig            INFO     Loading config file _tests/like_emulator.yaml
# [000729.53] [0/1] 07-31 18:25  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/primordial_cosmology.yaml
# [000730.00] [0/1] 07-31 18:25  LikelihoodPipeline        INFO     Found calculators [ShapeFitParameterizationLikelihood(like), Cosmoprimo(cosmo)].
# [000730.00] [0/1] 07-31 18:25  LikelihoodPipeline        INFO     Found end calculators [ShapeFitParameterizationLikelihood(like), Cosmoprimo(cosmo)].
# [000730.00] [0/1] 07-31 18:25  LikelihoodPipeline        INFO     Found likelihood like.
# [000730.03] [0/1] 07-31 18:25  EmceeSampler              INFO     Varied parameters: ['A_s'].
# [000731.04] [0/1] 07-31 18:25  EmceeSampler              INFO     Diagnostics:
# [000731.05] [0/1] 07-31 18:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.089 < 0.1.
# [000731.06] [0/1] 07-31 18:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.089.
# [000731.07] [0/1] 07-31 18:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.156.
# [000731.07] [0/1] 07-31 18:25  EmceeSampler              INFO     - max Geweke is 0.664.
# [000731.08] [0/1] 07-31 18:25  EmceeSampler              INFO     - max integrated autocorrelation time is 16.1.
# [000732.06] [0/1] 07-31 18:25  EmceeSampler              INFO     Diagnostics:
# [000732.07] [0/1] 07-31 18:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0797 < 0.1.
# [000732.08] [0/1] 07-31 18:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0797.
# [000732.09] [0/1] 07-31 18:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0271.
# [000732.09] [0/1] 07-31 18:25  EmceeSampler              INFO     - max Geweke is 0.887.
# [000732.10] [0/1] 07-31 18:25  EmceeSampler              INFO     - max integrated autocorrelation time is 15.2.
# [000732.10] [0/1] 07-31 18:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0622.

# %%
chain = sampler.chains[0].remove_burnin(0.5)
print(chain.to_stats(tablefmt='pretty'))
plotting.plot_triangle(chain)
# Out:
# +-----+----------+----------+----------+---------+-------------------+-------------------+
# |     |  argmax  |   mean   |  median  |   std   |  quantile:1sigma  |  interval:1sigma  |
# +-----+----------+----------+----------+---------+-------------------+-------------------+
# | A_s | 2.040e-9 | 2.038e-9 | 2.039e-9 | 1.3e-11 | -3.4e-12/+6.3e-12 | -3.0e-12/+6.5e-12 |
# +-----+----------+----------+----------+---------+-------------------+-------------------+
# Removed no burn in
