# %% [markdown]
# # Full shape examples
#
# In this notebook we will show how to perform full shape fits to data power spectrum, using Taylor expansion to speed likelihood evaluation.
# Look first at notebooks basic_examples.ipynb to get a flavor of *cosmofit* behaviour, and bao_examples.ipynb for application to BAO fits.

# %% [markdown]
# ## Fake power spectrum data

# %%
import numpy as np

from cosmoprimo.fiducial import DESI

cosmo = DESI()
edges = np.linspace(0., 0.3, 31)
k = (edges[:-1] + edges[1:]) / 2.
nmodes = 4. * np.pi / 3. * (edges[1:]**3 - edges[:-1]**3)
z = 1.
pk = cosmo.get_fourier().pk_interpolator()(k, z=z)
b = 2.
f = cosmo.growth_rate(z)
shotnoise = 1 / 1e-4
volume = 1e9

ells = (0, 2, 4)
poles = []
poles.append((b**2 + 2. / 3. * f * b + 1. / 5. * f**2) * pk + shotnoise)
poles.append((4. / 3. * f * b + 4. / 7. * f**2) * pk)
poles.append(8. / 35 * f**2 * pk)
poles = np.array(poles, dtype='f8')

from pypower import PowerSpectrumStatistics
mean = PowerSpectrumStatistics(edges, k, poles, nmodes=nmodes, ells=ells, shotnoise_nonorm=shotnoise, statistic='multipole')
cov = [2. * (2. * np.pi)**3 / (2 * ell + 1) / (volume * nmodes) * poles[0]**2 for ell in ells]
cov = np.diag(np.concatenate(cov, axis=0))

rng = np.random.RandomState(seed=42)
mocks = []
for i in range(1000):
    tmp = mean.deepcopy()
    tmp.power_nonorm.flat[...] = rng.multivariate_normal(mean.power_nonorm.ravel(), cov)
    mocks.append(tmp)

# %% [markdown]
# ## ShapeFit Likelihood

# %%
config = {}
config['like'] = {'class': 'cosmofit.likelihoods.PowerSpectrumMultipolesLikelihood',
                  'init': {'data': mocks, 'covariance': mocks, 'covariance_scale': True,
                           'klim': {0: [0.02, 0.2], 2: [0.02, 0.2]},  # fit monopole and quadrupole, between 0.02 and 0.2 h/Mpc
                           'zeff': z, 'fiducial': 'DESI'}}
# Here we use Kaiser power spectrum for fast calculation,
#  but there is also LPTTracerPowerSpectrumMultipoles based on Velocileptors
config['tracer'] = {'class': 'cosmofit.theories.full_shape.KaiserTracerPowerSpectrumMultipoles',
                    'params': {'b1': {'ref': {'dist': 'uniform', 'limits': [1.95, 2.05]}}},
                               'sn0': {'ref': {'dist': 'uniform', 'limits': [-50., 50.]}}}
                   # 'init': {'mu': 50}}  # only 50 mu (instead of 200) to speed up calculation in this notebook
config['param'] = {'class': 'cosmofit.theories.power_template.ShapeFitPowerSpectrumParameterization',
                    'params': {'dm': {'ref': {'dist': 'uniform', 'limits': [-0.01, 0.01]}},
                               'f': {'ref': {'dist': 'uniform', 'limits': [0.85, 0.88]}}},
                               'qp*r': {'ref': {'dist': 'uniform', 'limits': [0.99, 1.01]}}}
config['cosmo'] = {'class': 'cosmofit.theories.primordial_cosmology.Cosmoprimo'}

# NOTE: if we wanted to fit xi instead:
# config['like'] = {'class': 'cosmofit.likelihoods.CorrelationFunctionMultipolesLikelihood',
#                   'init': {'data': data, 'covariance': mocks,
#                            'slim': {0: [40., 160], 2: [40., 160]},  # fit monopole and quadrupole, between 40 and 160 Mpc/h
#                            'zeff': z, 'fiducial': 'DESI'}}
# config['tracer'] = {'class': 'cosmofit.theories.full_shape.KaiserTracerCorrelationFunctionMultipoles'}
# The rest would be the same

from cosmofit import LikelihoodPipeline, setup_logging

setup_logging()

likelihood = LikelihoodPipeline(config)
# Out:
# [000000.48] [0/1] 08-14 17:11  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/likelihoods/power_spectrum.yaml
# [000000.55] [0/1] 08-14 17:11  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/full_shape.yaml
# [000000.57] [0/1] 08-14 17:11  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000000.60] [0/1] 08-14 17:11  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/primordial_cosmology.yaml
# [000000.93] [0/1] 08-14 17:11  PowerSpectrumMultipolesLikelihood INFO     Covariance matrix with 36 points built from 1000 observations.
# [000000.93] [0/1] 08-14 17:11  PowerSpectrumMultipolesLikelihood INFO     ...resulting in Hartlap factor of 0.9630.
# [000000.93] [0/1] 08-14 17:11  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000000.94] [0/1] 08-14 17:11  PipelineConfig            INFO     No config for WindowedPowerSpectrumMultipoles found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000000.97] [0/1] 08-14 17:11  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000001.03] [0/1] 08-14 17:11  PipelineConfig            INFO     No config for ShapeFitPowerSpectrumTemplate found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000001.48] [0/1] 08-14 17:11  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000001.52] [0/1] 08-14 17:11  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000001.54] [0/1] 08-14 17:11  LikelihoodPipeline        INFO     Found calculators [PowerSpectrumMultipolesLikelihood(like), WindowedPowerSpectrumMultipoles(theory), KaiserTracerPowerSpectrumMultipoles(tracer), ShapeFitPowerSpectrumParameterization(param), ShapeFitPowerSpectrumTemplate(template), Cosmoprimo(cosmo), BasePowerSpectrumWiggles(wiggles), EffectAP(effectap)].
# [000001.54] [0/1] 08-14 17:11  LikelihoodPipeline        INFO     Found end calculators [PowerSpectrumMultipolesLikelihood(like)].
# [000002.33] [0/1] 08-14 17:11  LikelihoodPipeline        INFO     Found likelihood like.

# %%
from cosmofit.base import BasePipeline
from cosmofit.emulators import TaylorEmulatorEngine

pipeline = likelihood.select('tracer', type=BasePipeline)
emulator = TaylorEmulatorEngine(pipeline, order={'*': 2, 'sn0': 1})  # order 2 except for sn0 (order 1 is enough)
emulator.set_samples()
emulator.fit()
emulator.check()
emulator.plot(name='power')

import os
base_dir = '_tests'
kaiser_emulator_fn = os.path.join(base_dir, 'kaiser_emulator.npy')
emulator.save(kaiser_emulator_fn)
# Out:
# [000002.50] [0/1] 08-14 17:11  BasePipeline              WARNING  Derived parameter zeff of ShapeFitPowerSpectrumTemplate(template) is already derived in KaiserTracerPowerSpectrumMultipoles(tracer).
# [000002.50] [0/1] 08-14 17:11  TaylorEmulatorEngine      INFO     Varied parameters: ['sn0', 'b1', 'f', 'dm', 'qpar', 'qper'].
# [000002.51] [0/1] 08-14 17:11  TaylorEmulatorEngine      INFO     Found varying {'DH_over_DM', 'DH_over_rd', 'm', 'DM_over_rd', 'DV_over_rd', 'f_sqrt_A_p', 'power'} and fixed ['A_p', 'n', 'zeff', 'k', 'ells', 'fiducial'] outputs.
# [000004.61] [0/1] 08-14 17:11  TaylorEmulatorEngine      INFO     Diagnostics:
# [000004.90] [0/1] 08-14 17:11  TaylorEmulatorEngine      INFO     - mse of DH_over_DM is 2.94e-24 (square root = 1.71e-12).
# [000004.90] [0/1] 08-14 17:11  TaylorEmulatorEngine      INFO     - mse of DH_over_rd is 2.31e-30 (square root = 1.52e-15).
# [000004.90] [0/1] 08-14 17:11  TaylorEmulatorEngine      INFO     - mse of m is 0 (square root = 0).
# [000004.90] [0/1] 08-14 17:11  TaylorEmulatorEngine      INFO     - mse of DM_over_rd is 2.31e-30 (square root = 1.52e-15).
# [000004.90] [0/1] 08-14 17:11  TaylorEmulatorEngine      INFO     - mse of DV_over_rd is 1.64e-23 (square root = 4.05e-12).
# [000004.90] [0/1] 08-14 17:11  TaylorEmulatorEngine      INFO     - mse of f_sqrt_A_p is 0 (square root = 0).
# [000004.90] [0/1] 08-14 17:11  TaylorEmulatorEngine      INFO     - mse of power is 4.01e-15 (square root = 6.33e-08).
# [000005.30] [0/1] 08-14 17:11  TaylorEmulatorEngine      INFO     Saving _tests/kaiser_emulator.npy.
# [000005.30] [0/1] 08-14 17:11  TaylorEmulatorEngine      INFO     Saving _tests/kaiser_emulator.yaml.

# %% [markdown]
# ## Sampling
# Let us draw MC samples of the likelihood (actually posterior, including parameter priors).

# %%
from cosmofit.samplers import EmceeSampler

config['tracer']['load'] = kaiser_emulator_fn
del config['param'], config['cosmo']
likelihood = LikelihoodPipeline(config)

sampler = EmceeSampler(likelihood, seed=42)
converged = False
while not converged:
    sampler.run(niterations=500)
    converged = sampler.check(eigen_gr_stop=0.1)
# Out:
# [000005.89] [0/1] 08-14 17:11  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/likelihoods/power_spectrum.yaml
# [000005.89] [0/1] 08-14 17:11  KaiserTracerPowerSpectrumMultipoles INFO     Loading _tests/kaiser_emulator.npy.
# [000005.91] [0/1] 08-14 17:11  PipelineConfig            INFO     Loading config file _tests/kaiser_emulator.yaml
# [000006.25] [0/1] 08-14 17:11  PowerSpectrumMultipolesLikelihood INFO     Covariance matrix with 36 points built from 1000 observations.
# [000006.25] [0/1] 08-14 17:11  PowerSpectrumMultipolesLikelihood INFO     ...resulting in Hartlap factor of 0.9630.
# [000006.25] [0/1] 08-14 17:11  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000006.26] [0/1] 08-14 17:11  PipelineConfig            INFO     No config for WindowedPowerSpectrumMultipoles found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/base.yaml
# [000006.30] [0/1] 08-14 17:11  LikelihoodPipeline        INFO     Found calculators [PowerSpectrumMultipolesLikelihood(like), WindowedPowerSpectrumMultipoles(theory), KaiserTracerPowerSpectrumMultipoles(tracer)].
# [000006.30] [0/1] 08-14 17:11  LikelihoodPipeline        INFO     Found end calculators [PowerSpectrumMultipolesLikelihood(like)].
# [000006.31] [0/1] 08-14 17:11  LikelihoodPipeline        INFO     Found likelihood like.
# [000006.40] [0/1] 08-14 17:11  EmceeSampler              INFO     Varied parameters: ['sn0', 'f', 'dm', 'qpar', 'qper', 'b1'].
# [000034.35] [0/1] 08-14 17:11  EmceeSampler              INFO     Diagnostics:
# [000034.39] [0/1] 08-14 17:11  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 4.45 > 0.1.
# [000034.49] [0/1] 08-14 17:11  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 1.13.
# [000034.57] [0/1] 08-14 17:11  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 1.49.
# [000034.58] [0/1] 08-14 17:11  EmceeSampler              INFO     - max Geweke is 1.52.
# [000034.67] [0/1] 08-14 17:11  EmceeSampler              INFO     - max integrated autocorrelation time is 35.5.
# [000064.23] [0/1] 08-14 17:12  EmceeSampler              INFO     Diagnostics:
# [000064.27] [0/1] 08-14 17:12  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 2.03 > 0.1.
# [000064.34] [0/1] 08-14 17:12  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 1.6.
# [000064.44] [0/1] 08-14 17:12  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 2.42.
# [000064.46] [0/1] 08-14 17:12  EmceeSampler              INFO     - max Geweke is 2.12.
# [000064.54] [0/1] 08-14 17:12  EmceeSampler              INFO     - max integrated autocorrelation time is 49.3.
# [000064.54] [0/1] 08-14 17:12  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.364.
# [000094.13] [0/1] 08-14 17:12  EmceeSampler              INFO     Diagnostics:
# [000094.18] [0/1] 08-14 17:12  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 2 > 0.1.
# [000094.28] [0/1] 08-14 17:12  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 1.58.
# [000094.37] [0/1] 08-14 17:12  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 2.63.
# [000094.39] [0/1] 08-14 17:12  EmceeSampler              INFO     - max Geweke is 0.566.
# [000094.48] [0/1] 08-14 17:12  EmceeSampler              INFO     - max integrated autocorrelation time is 67.3.
# [000094.48] [0/1] 08-14 17:12  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.267.
# [000126.21] [0/1] 08-14 17:13  EmceeSampler              INFO     Diagnostics:
# [000126.27] [0/1] 08-14 17:13  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.509 > 0.1.
# [000126.35] [0/1] 08-14 17:13  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.444.
# [000126.45] [0/1] 08-14 17:13  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 1.09.
# [000126.47] [0/1] 08-14 17:13  EmceeSampler              INFO     - max Geweke is 3.09.
# [000126.58] [0/1] 08-14 17:13  EmceeSampler              INFO     - max integrated autocorrelation time is 82.1.
# [000126.58] [0/1] 08-14 17:13  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.18.
# [000154.83] [0/1] 08-14 17:13  EmceeSampler              INFO     Diagnostics:
# [000154.87] [0/1] 08-14 17:13  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.249 > 0.1.
# [000154.96] [0/1] 08-14 17:13  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.186.
# [000155.07] [0/1] 08-14 17:13  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.421.
# [000155.09] [0/1] 08-14 17:13  EmceeSampler              INFO     - max Geweke is 2.85.
# [000155.18] [0/1] 08-14 17:13  EmceeSampler              INFO     - max integrated autocorrelation time is 89.2.
# [000155.18] [0/1] 08-14 17:13  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0877.
# [000186.14] [0/1] 08-14 17:14  EmceeSampler              INFO     Diagnostics:
# [000186.19] [0/1] 08-14 17:14  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.478 > 0.1.
# [000186.31] [0/1] 08-14 17:14  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.41.
# [000186.42] [0/1] 08-14 17:14  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.651.
# [000186.45] [0/1] 08-14 17:14  EmceeSampler              INFO     - max Geweke is 1.32.
# [000186.57] [0/1] 08-14 17:14  EmceeSampler              INFO     - max integrated autocorrelation time is 100.
# [000186.57] [0/1] 08-14 17:14  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.111.
# [000215.00] [0/1] 08-14 17:14  EmceeSampler              INFO     Diagnostics:
# [000215.06] [0/1] 08-14 17:14  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.402 > 0.1.
# [000215.12] [0/1] 08-14 17:14  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.342.
# [000215.24] [0/1] 08-14 17:14  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.526.
# [000215.25] [0/1] 08-14 17:14  EmceeSampler              INFO     - max Geweke is 0.5.
# [000215.38] [0/1] 08-14 17:14  EmceeSampler              INFO     - max integrated autocorrelation time is 106.
# [000215.38] [0/1] 08-14 17:14  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0518.
# [000243.56] [0/1] 08-14 17:15  EmceeSampler              INFO     Diagnostics:
# [000243.62] [0/1] 08-14 17:15  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.317 > 0.1.
# [000243.68] [0/1] 08-14 17:15  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.276.
# [000243.81] [0/1] 08-14 17:15  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.275.
# [000243.84] [0/1] 08-14 17:15  EmceeSampler              INFO     - max Geweke is 0.273.
# [000244.01] [0/1] 08-14 17:15  EmceeSampler              INFO     - max integrated autocorrelation time is 107.
# [000244.01] [0/1] 08-14 17:15  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0399.
# [000272.77] [0/1] 08-14 17:15  EmceeSampler              INFO     Diagnostics:
# [000272.83] [0/1] 08-14 17:15  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.254 > 0.1.
# [000272.94] [0/1] 08-14 17:15  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.221.
# [000273.09] [0/1] 08-14 17:15  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.192.
# [000273.10] [0/1] 08-14 17:15  EmceeSampler              INFO     - max Geweke is 0.449.
# [000273.23] [0/1] 08-14 17:15  EmceeSampler              INFO     - max integrated autocorrelation time is 107.
# [000273.23] [0/1] 08-14 17:15  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0334.
# [000303.62] [0/1] 08-14 17:16  EmceeSampler              INFO     Diagnostics:
# [000303.69] [0/1] 08-14 17:16  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.201 > 0.1.
# [000303.81] [0/1] 08-14 17:16  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.172.
# [000303.96] [0/1] 08-14 17:16  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.167.
# [000303.98] [0/1] 08-14 17:16  EmceeSampler              INFO     - max Geweke is 0.241.
# [000304.11] [0/1] 08-14 17:16  EmceeSampler              INFO     - max integrated autocorrelation time is 106.
# [000304.11] [0/1] 08-14 17:16  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0221.
# [000332.97] [0/1] 08-14 17:16  EmceeSampler              INFO     Diagnostics:
# [000333.03] [0/1] 08-14 17:16  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.174 > 0.1.
# [000333.09] [0/1] 08-14 17:16  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.147.
# [000333.24] [0/1] 08-14 17:16  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0858.
# [000333.26] [0/1] 08-14 17:16  EmceeSampler              INFO     - max Geweke is 0.333.
# [000333.38] [0/1] 08-14 17:16  EmceeSampler              INFO     - max integrated autocorrelation time is 108.
# [000333.38] [0/1] 08-14 17:16  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0307.
# [000361.36] [0/1] 08-14 17:17  EmceeSampler              INFO     Diagnostics:
# [000361.43] [0/1] 08-14 17:17  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.154 > 0.1.
# [000361.54] [0/1] 08-14 17:17  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.126.
# [000361.69] [0/1] 08-14 17:17  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.039.
# [000361.71] [0/1] 08-14 17:17  EmceeSampler              INFO     - max Geweke is 0.259.
# [000361.86] [0/1] 08-14 17:17  EmceeSampler              INFO     - max integrated autocorrelation time is 107.
# [000361.86] [0/1] 08-14 17:17  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0455.
# [000390.67] [0/1] 08-14 17:17  EmceeSampler              INFO     Diagnostics:
# [000390.73] [0/1] 08-14 17:17  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.133 > 0.1.
# [000390.84] [0/1] 08-14 17:17  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.105.
# [000391.00] [0/1] 08-14 17:17  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0602.
# [000391.02] [0/1] 08-14 17:17  EmceeSampler              INFO     - max Geweke is 0.232.
# [000391.17] [0/1] 08-14 17:17  EmceeSampler              INFO     - max integrated autocorrelation time is 106.
# [000391.17] [0/1] 08-14 17:17  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.019.
# [000419.79] [0/1] 08-14 17:18  EmceeSampler              INFO     Diagnostics:
# [000419.84] [0/1] 08-14 17:18  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.118 > 0.1.
# [000419.91] [0/1] 08-14 17:18  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0879.
# [000420.06] [0/1] 08-14 17:18  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0428.
# [000420.08] [0/1] 08-14 17:18  EmceeSampler              INFO     - max Geweke is 0.26.
# [000420.22] [0/1] 08-14 17:18  EmceeSampler              INFO     - max integrated autocorrelation time is 107.
# [000420.22] [0/1] 08-14 17:18  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0205.
# [000448.11] [0/1] 08-14 17:18  EmceeSampler              INFO     Diagnostics:
# [000448.16] [0/1] 08-14 17:18  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.113 > 0.1.
# [000448.21] [0/1] 08-14 17:18  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0854.
# [000448.38] [0/1] 08-14 17:18  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0453.
# [000448.41] [0/1] 08-14 17:18  EmceeSampler              INFO     - max Geweke is 0.376.
# [000448.56] [0/1] 08-14 17:18  EmceeSampler              INFO     - max integrated autocorrelation time is 107.
# [000448.56] [0/1] 08-14 17:18  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0151.
# [000476.64] [0/1] 08-14 17:19  EmceeSampler              INFO     Diagnostics:
# [000476.69] [0/1] 08-14 17:19  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.106 > 0.1.
# [000476.80] [0/1] 08-14 17:19  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0801.
# [000476.98] [0/1] 08-14 17:19  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0345.
# [000476.99] [0/1] 08-14 17:19  EmceeSampler              INFO     - max Geweke is 0.341.
# [000477.13] [0/1] 08-14 17:19  EmceeSampler              INFO     - max integrated autocorrelation time is 110 (reliable).
# [000477.13] [0/1] 08-14 17:19  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0258.
# [000506.35] [0/1] 08-14 17:19  EmceeSampler              INFO     Diagnostics:
# [000506.40] [0/1] 08-14 17:19  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.097 < 0.1.
# [000506.51] [0/1] 08-14 17:19  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0721.
# [000506.69] [0/1] 08-14 17:19  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0308.
# [000506.71] [0/1] 08-14 17:19  EmceeSampler              INFO     - max Geweke is 0.423.
# [000506.85] [0/1] 08-14 17:19  EmceeSampler              INFO     - max integrated autocorrelation time is 109 (reliable).
# [000506.85] [0/1] 08-14 17:19  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.02.
# [000535.90] [0/1] 08-14 17:20  EmceeSampler              INFO     Diagnostics:
# [000535.96] [0/1] 08-14 17:20  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0939 < 0.1.
# [000536.07] [0/1] 08-14 17:20  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0675.
# [000536.29] [0/1] 08-14 17:20  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0402.
# [000536.31] [0/1] 08-14 17:20  EmceeSampler              INFO     - max Geweke is 0.421.
# [000536.45] [0/1] 08-14 17:20  EmceeSampler              INFO     - max integrated autocorrelation time is 108 (reliable).
# [000536.45] [0/1] 08-14 17:20  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0132.

# %%
likelihood.end_calculators[0].plot()
# Out:
# array([<AxesSubplot:ylabel='$k P_{\\ell}(k)$ [$(\\mathrm{Mpc}/h)^{2}$]'>,
#        <AxesSubplot:ylabel='$\\Delta P_{0} / \\sigma_{ P_{0} }$'>,
#        <AxesSubplot:xlabel='$k$ [$h/\\mathrm{Mpc}$]', ylabel='$\\Delta P_{2} / \\sigma_{ P_{2} }$'>],
#       dtype=object)

# %%
chain = sampler.chains[0].remove_burnin(0.5)
print(chain.to_stats(tablefmt='pretty'))
# For some reason, b1 is a bit biased (maybe integration accuracy?)
# Out:
# +------+---------+---------+---------+--------+------------------+-------------------+
# |      | argmax  |  mean   | median  |  std   | quantile:1sigma  |  interval:1sigma  |
# +------+---------+---------+---------+--------+------------------+-------------------+
# | sn0  |   -7    |   -8    |   -7    |   35   |    -4.9/+7.0     |     -5.1/+6.7     |
# |  f   | 0.8664  | 0.8663  | 0.8664  | 0.0010 | -8.3e-4/+8.6e-4  |  -8.6e-4/+8.2e-4  |
# |  dm  | -0.0024 | -0.0022 | -0.0023 | 0.0013 | -0.0011/+0.0010  | -0.00126/+0.00088 |
# | qpar | 1.0004  | 1.0002  | 1.0003  | 0.0012 | -4.5e-4/+6.2e-4  |  -4.0e-4/+6.6e-4  |
# | qper | 1.0017  | 1.0014  | 1.0015  | 0.0020 | -8.1e-4/+1.11e-3 | -7.3e-4/+1.19e-3  |
# |  b1  | 1.9776  | 1.9780  | 1.9778  | 0.0027 | -0.0017/+0.0014  |  -0.0018/+0.0013  |
# +------+---------+---------+---------+--------+------------------+-------------------+

# %%
from cosmofit.samples import plotting
plotting.plot_triangle(chain)
# Out:
# [000537.27] [0/1] 08-14 17:20  numexpr.utils             INFO     NumExpr defaulting to 8 threads.
# Removed no burn in
# [000537.63] [0/1] 08-14 17:20  root                      WARNING  fine_bins not large enough to well sample smoothing scale - sn0
# [000538.03] [0/1] 08-14 17:20  root                      WARNING  fine_bins not large enough to well sample smoothing scale - qpar
# [000538.12] [0/1] 08-14 17:20  root                      WARNING  fine_bins not large enough to well sample smoothing scale - qper
# [000538.26] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, f
# [000538.39] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, dm
# [000538.57] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, qpar
# [000538.69] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, qper
# [000538.81] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: sn0, b1
# [000539.12] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: f, qpar
# [000539.26] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: f, qper
# [000539.43] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: f, b1
# [000539.58] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: dm, qpar
# [000539.74] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: dm, qper
# [000540.08] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: dm, b1
# [000540.23] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: qpar, qper
# [000540.49] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: qpar, b1
# [000540.71] [0/1] 08-14 17:20  root                      WARNING  fine_bins_2D not large enough for optimal density: qper, b1
# [000540.98] [0/1] 08-14 17:20  matplotlib.mathtext       INFO     Substituting symbol \perp from STIXGeneral
# [000540.98] [0/1] 08-14 17:20  matplotlib.mathtext       INFO     Substituting symbol \perp from STIXGeneral
# [000543.34] [0/1] 08-14 17:20  matplotlib.mathtext       INFO     Substituting symbol \perp from STIXGeneral
# [000543.34] [0/1] 08-14 17:20  matplotlib.mathtext       INFO     Substituting symbol \perp from STIXGeneral

# %% [markdown]
# ## Post-processing

# %%
fs_chain = sampler.chains[0]

# %%
import os
base_dir = '_tests'
shapefit_emulator_fn = os.path.join(base_dir, 'shapefit_emulator.npy')

config = {}
config['like'] = {'class': 'cosmofit.likelihoods.ShapeFitParameterizationLikelihood',
                  'init': {'chains': fs_chain, 'burnin': 0.5}}
config['theory'] = {'class': 'cosmofit.likelihoods.clustering.ShapeFitModel',
                    'emulator': {'save': shapefit_emulator_fn}}
config['cosmo'] = {'class': 'cosmofit.theories.primordial_cosmology.Cosmoprimo',
                   'init': {'fiducial': 'DESI'},
                   'params': {'.delete': 'omega_cdm',
                              'Omega_m': {'fixed': False, 'prior': {'dist': 'uniform', 'limits': [0.05, 0.6]},
                                          'ref': {'dist': 'uniform', 'limits': [0.30, 0.33]}, 'latex': '\Omega_{m}'},
                               'A_s': {'fixed': False,
                                       'prior': {'dist': 'uniform', 'limits': [1.8e-9, 3e-9]},
                                       'ref': {'dist': 'uniform', 'limits': [1.9e-9, 2.1e-9]}},
                               'h': {'fixed': False,
                                     'prior': {'dist': 'uniform', 'limits': [0.4, 0.9]},
                                     'ref': {'dist': 'uniform', 'limits': [0.65, 0.70]}}}}

# %%
likelihood = LikelihoodPipeline(config)

from cosmofit.emulators import EmulatorConfig
config_emulator = EmulatorConfig({'class': 'TaylorEmulatorEngine', 'init': {'order': 3.}, 'sample': {'scale': 1e-1}, 'check': None})
config_emulator.run(likelihood.copy(type=BasePipeline))
# Out:
# [000543.92] [0/1] 08-14 17:20  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/primordial_cosmology.yaml
# [000543.97] [0/1] 08-14 17:20  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000544.00] [0/1] 08-14 17:20  PipelineConfig            INFO     No config for BAOExtractor found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000544.48] [0/1] 08-14 17:20  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000544.51] [0/1] 08-14 17:20  PipelineConfig            INFO     No config for ShapeFitPowerSpectrumExtractor found in config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000544.53] [0/1] 08-14 17:20  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/power_template.yaml
# [000544.57] [0/1] 08-14 17:20  LikelihoodPipeline        INFO     Found calculators [ShapeFitParameterizationLikelihood(like), ShapeFitModel(theory), BAOExtractor(bao), Cosmoprimo(cosmo), ShapeFitPowerSpectrumExtractor(shapefit), BasePowerSpectrumWiggles(wiggles)].
# [000544.57] [0/1] 08-14 17:20  LikelihoodPipeline        INFO     Found end calculators [ShapeFitParameterizationLikelihood(like)].
# [000545.63] [0/1] 08-14 17:20  ShapeFitParameterizationLikelihood INFO     Fitting input samples [Parameter(m, fixed), Parameter(f_sqrt_A_p, fixed), Parameter(DM_over_rd, fixed), Parameter(DH_over_rd, fixed)].
# [000545.65] [0/1] 08-14 17:20  LikelihoodPipeline        INFO     Found likelihood like.
# [000548.69] [0/1] 08-14 17:20  TaylorEmulatorEngine      INFO     Varied parameters: ['Omega_m', 'A_s', 'h'].
# [000548.69] [0/1] 08-14 17:20  TaylorEmulatorEngine      INFO     Found varying {'theory'} and fixed ['quantities'] outputs.
# [000712.00] [0/1] 08-14 17:23  TaylorEmulatorEngine      INFO     Diagnostics:
# [000712.16] [0/1] 08-14 17:23  TaylorEmulatorEngine      INFO     - mse of theory is 1.07e-09 (square root = 3.27e-05).
# [000712.16] [0/1] 08-14 17:23  TaylorEmulatorEngine      INFO     Saving _tests/shapefit_emulator.npy.
# [000712.16] [0/1] 08-14 17:23  TaylorEmulatorEngine      INFO     Saving _tests/shapefit_emulator.yaml.

# %%
config['theory']['load'] = shapefit_emulator_fn
likelihood = LikelihoodPipeline(config)

from cosmofit.samplers import EmceeSampler

sampler = EmceeSampler(likelihood, seed=42)
converged = False
while not converged:
    sampler.run()
    converged = sampler.check(eigen_gr_stop=0.01)
# Out:
# [000712.18] [0/1] 08-14 17:23  ShapeFitModel             INFO     Loading _tests/shapefit_emulator.npy.
# [000712.20] [0/1] 08-14 17:23  PipelineConfig            INFO     Loading config file _tests/shapefit_emulator.yaml
# [000712.23] [0/1] 08-14 17:23  PipelineConfig            INFO     Loading config file /local/home/adematti/Desktop/DESI/NERSC/cosmodesi/cosmofit/cosmofit/theories/primordial_cosmology.yaml
# [000712.99] [0/1] 08-14 17:23  LikelihoodPipeline        INFO     Found calculators [ShapeFitParameterizationLikelihood(like), ShapeFitModel(theory), Cosmoprimo(cosmo)].
# [000713.00] [0/1] 08-14 17:23  LikelihoodPipeline        INFO     Found end calculators [ShapeFitParameterizationLikelihood(like), Cosmoprimo(cosmo)].
# [000713.00] [0/1] 08-14 17:23  ShapeFitParameterizationLikelihood INFO     Fitting input samples [Parameter(m, fixed), Parameter(f_sqrt_A_p, fixed), Parameter(DM_over_rd, fixed), Parameter(DH_over_rd, fixed)].
# [000713.03] [0/1] 08-14 17:23  LikelihoodPipeline        INFO     Found likelihood like.
# [000713.05] [0/1] 08-14 17:23  EmceeSampler              INFO     Varied parameters: ['Omega_m', 'A_s', 'h'].
# [000715.85] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000715.86] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.208 > 0.01.
# [000715.88] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0165.
# [000715.91] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.249.
# [000715.92] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.442.
# [000715.94] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 15.3.
# [000718.70] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000718.71] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 1.17 > 0.01.
# [000718.73] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.652.
# [000718.76] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.99.
# [000718.77] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.54.
# [000718.79] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 24.1.
# [000718.79] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.43.
# [000721.57] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000721.59] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.692 > 0.01.
# [000721.60] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.407.
# [000721.63] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.3.
# [000721.63] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.911.
# [000721.65] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 34.5.
# [000721.66] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.327.
# [000724.26] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000724.28] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.438 > 0.01.
# [000724.30] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.254.
# [000724.33] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.151.
# [000724.34] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.769.
# [000724.36] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 44.3.
# [000724.36] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.364.
# [000727.04] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000727.05] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.157 > 0.01.
# [000727.07] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.103.
# [000727.10] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0409.
# [000727.10] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.897.
# [000727.13] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 50.7.
# [000727.13] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.134.
# [000729.78] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000729.80] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.208 > 0.01.
# [000729.82] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.163.
# [000729.85] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0884.
# [000729.86] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.933.
# [000729.89] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 49.5.
# [000729.90] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0234.
# [000732.74] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000732.76] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.209 > 0.01.
# [000732.79] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.16.
# [000732.84] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.118.
# [000732.85] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.479.
# [000732.89] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 57.
# [000732.89] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.131.
# [000735.83] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000735.85] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.182 > 0.01.
# [000735.88] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.135.
# [000735.95] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.087.
# [000735.96] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.222.
# [000735.98] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 52.6.
# [000735.98] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0833.
# [000738.70] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000738.71] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.148 > 0.01.
# [000738.73] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.115.
# [000738.76] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.117.
# [000738.77] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.134.
# [000738.81] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 51.6.
# [000738.81] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0205.
# [000741.49] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000741.51] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.141 > 0.01.
# [000741.53] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.104.
# [000741.56] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.111.
# [000741.57] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.221.
# [000741.61] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 52.7.
# [000741.61] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0392.
# [000744.30] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000744.32] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.118 > 0.01.
# [000744.33] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0925.
# [000744.37] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0754.
# [000744.38] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.311.
# [000744.42] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 57.
# [000744.42] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0748.
# [000747.06] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000747.08] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.105 > 0.01.
# [000747.09] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0793.
# [000747.13] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0747.
# [000747.13] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.295.
# [000747.16] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 53.4.
# [000747.16] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0671.
# [000749.94] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000749.96] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0837 > 0.01.
# [000749.97] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0642.
# [000750.01] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0608.
# [000750.01] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.358.
# [000750.03] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 51.2 (reliable).
# [000750.03] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0432.
# [000752.79] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000752.81] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0646 > 0.01.
# [000752.85] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0534.
# [000752.92] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0605.
# [000752.94] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.229.
# [000752.99] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 50 (reliable).
# [000752.99] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0288.
# [000755.71] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000755.72] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0663 > 0.01.
# [000755.74] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0547.
# [000755.77] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0752.
# [000755.78] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.167.
# [000755.80] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 48.5 (reliable).
# [000755.80] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0299.
# [000758.69] [0/1] 08-14 17:23  EmceeSampler              INFO     Diagnostics:
# [000758.70] [0/1] 08-14 17:23  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0525 > 0.01.
# [000758.72] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0469.
# [000758.76] [0/1] 08-14 17:23  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0755.
# [000758.77] [0/1] 08-14 17:23  EmceeSampler              INFO     - max Geweke is 0.19.
# [000758.81] [0/1] 08-14 17:23  EmceeSampler              INFO     - max integrated autocorrelation time is 46.5 (reliable).
# [000758.81] [0/1] 08-14 17:23  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0444.
# [000761.67] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000761.68] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0436 > 0.01.
# [000761.70] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0418.
# [000761.74] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0775.
# [000761.75] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.203.
# [000761.77] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 46.1 (reliable).
# [000761.77] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0163.
# [000764.80] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000764.81] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0396 > 0.01.
# [000764.83] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.037.
# [000764.87] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.066.
# [000764.87] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.201.
# [000764.90] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 45.7 (reliable).
# [000764.90] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.013.
# [000767.70] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000767.71] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0385 > 0.01.
# [000767.73] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0362.
# [000767.77] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0409.
# [000767.77] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.223.
# [000767.80] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 43.5 (reliable).
# [000767.80] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.051.
# [000770.37] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000770.39] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0383 > 0.01.
# [000770.40] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0342.
# [000770.44] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0483.
# [000770.45] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.313.
# [000770.48] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 44.3 (reliable).
# [000770.48] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0189.
# [000773.05] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000773.06] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0407 > 0.01.
# [000773.08] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0356.
# [000773.12] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0319.
# [000773.12] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.351.
# [000773.15] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 46.7 (reliable).
# [000773.15] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.051.
# [000775.72] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000775.73] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0503 > 0.01.
# [000775.75] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0365.
# [000775.79] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0378.
# [000775.80] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.373.
# [000775.83] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 46.1 (reliable).
# [000775.83] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0141.
# [000778.41] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000778.43] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0589 > 0.01.
# [000778.44] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.037.
# [000778.48] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0136.
# [000778.49] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.392.
# [000778.52] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 46.1 (reliable).
# [000778.52] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00358.
# [000781.48] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000781.51] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0574 > 0.01.
# [000781.53] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0315.
# [000781.58] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0237.
# [000781.59] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.421.
# [000781.62] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 47.4 (reliable).
# [000781.62] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0258.
# [000784.35] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000784.37] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.033 > 0.01.
# [000784.38] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0193.
# [000784.43] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0142.
# [000784.44] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.47.
# [000784.46] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 46.9 (reliable).
# [000784.47] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00924.
# [000787.05] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000787.06] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0309 > 0.01.
# [000787.08] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0183.
# [000787.12] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0125.
# [000787.13] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.457.
# [000787.16] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 46.6 (reliable).
# [000787.16] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00645.
# [000789.85] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000789.87] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0173 > 0.01.
# [000789.88] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0149.
# [000789.93] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0291.
# [000789.94] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.452.
# [000789.97] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 45.9 (reliable).
# [000789.97] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0159.
# [000792.85] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000792.88] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0216 > 0.01.
# [000792.93] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0142.
# [000793.03] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.026.
# [000793.04] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.452.
# [000793.07] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 45.8 (reliable).
# [000793.07] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0223.
# [000795.79] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000795.81] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0215 > 0.01.
# [000795.84] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0131.
# [000795.90] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0164.
# [000795.92] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.45.
# [000795.98] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 44.6 (reliable).
# [000795.98] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0309.
# [000798.67] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000798.69] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.025 > 0.01.
# [000798.70] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0128.
# [000798.76] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0125.
# [000798.77] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.45.
# [000798.79] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 44.1 (reliable).
# [000798.80] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0127.
# [000801.57] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000801.59] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0249 > 0.01.
# [000801.61] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.012.
# [000801.66] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0117.
# [000801.67] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.445.
# [000801.70] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 44 (reliable).
# [000801.70] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.000986.
# [000804.85] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000804.87] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0248 > 0.01.
# [000804.88] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.011.
# [000804.94] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.016.
# [000804.94] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.43.
# [000804.97] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 43 (reliable).
# [000804.97] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0247.
# [000807.82] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000807.83] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0203 > 0.01.
# [000807.85] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0109.
# [000807.92] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0192.
# [000807.92] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.386.
# [000807.95] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 42.9 (reliable).
# [000807.95] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00872.
# [000810.70] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000810.72] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0193 > 0.01.
# [000810.74] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0104.
# [000810.82] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0219.
# [000810.83] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.375.
# [000810.85] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 43.2 (reliable).
# [000810.85] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0087.
# [000813.62] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000813.64] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0198 > 0.01.
# [000813.66] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00933.
# [000813.71] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0188.
# [000813.72] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.378.
# [000813.75] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 43.2 (reliable).
# [000813.75] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0032.
# [000816.42] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000816.44] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0158 > 0.01.
# [000816.45] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0108.
# [000816.51] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0237.
# [000816.52] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.361.
# [000816.55] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 43.7 (reliable).
# [000816.55] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0113.
# [000819.12] [0/1] 08-14 17:24  EmceeSampler              INFO     Diagnostics:
# [000819.14] [0/1] 08-14 17:24  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.012 > 0.01.
# [000819.15] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0114.
# [000819.21] [0/1] 08-14 17:24  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0295.
# [000819.22] [0/1] 08-14 17:24  EmceeSampler              INFO     - max Geweke is 0.364.
# [000819.25] [0/1] 08-14 17:24  EmceeSampler              INFO     - max integrated autocorrelation time is 43.9 (reliable).
# [000819.25] [0/1] 08-14 17:24  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0107.
# [000821.84] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000821.85] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0153 > 0.01.
# [000821.87] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0117.
# [000821.93] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0222.
# [000821.94] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.38.
# [000821.97] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 44.1 (reliable).
# [000821.97] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0176.
# [000824.54] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000824.56] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0118 > 0.01.
# [000824.57] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00932.
# [000824.63] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.014.
# [000824.64] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.38.
# [000824.67] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 44 (reliable).
# [000824.67] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00677.
# [000827.24] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000827.26] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.016 > 0.01.
# [000827.28] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0106.
# [000827.34] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0216.
# [000827.35] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.378.
# [000827.39] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 43.9 (reliable).
# [000827.39] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00589.
# [000829.98] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000830.00] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0208 > 0.01.
# [000830.01] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00957.
# [000830.07] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0088.
# [000830.08] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.371.
# [000830.13] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 43.7 (reliable).
# [000830.13] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00551.
# [000832.73] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000832.75] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0172 > 0.01.
# [000832.78] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00918.
# [000832.85] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0144.
# [000832.85] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.363.
# [000832.90] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 43.5 (reliable).
# [000832.90] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0133.
# [000835.46] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000835.48] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0121 > 0.01.
# [000835.49] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00843.
# [000835.56] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0147.
# [000835.56] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.358.
# [000835.61] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 43.8 (reliable).
# [000835.61] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00674.
# [000838.17] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000838.19] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0158 > 0.01.
# [000838.21] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00761.
# [000838.27] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00997.
# [000838.28] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.36.
# [000838.33] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 44.4 (reliable).
# [000838.33] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0146.
# [000840.88] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000840.89] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0143 > 0.01.
# [000840.92] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00776.
# [000841.02] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0121.
# [000841.03] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.366.
# [000841.12] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 44.1 (reliable).
# [000841.12] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0069.
# [000843.83] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000843.85] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0151 > 0.01.
# [000843.88] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00846.
# [000843.95] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0075.
# [000843.97] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.357.
# [000844.02] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 43.6 (reliable).
# [000844.02] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0118.
# [000846.68] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000846.70] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0183 > 0.01.
# [000846.72] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00782.
# [000846.79] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00833.
# [000846.80] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.337.
# [000846.85] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 44.8 (reliable).
# [000846.85] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0267.
# [000849.44] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000849.46] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0155 > 0.01.
# [000849.47] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00718.
# [000849.54] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00968.
# [000849.55] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.335.
# [000849.60] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 43.7 (reliable).
# [000849.60] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0254.
# [000852.19] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000852.21] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0148 > 0.01.
# [000852.23] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00642.
# [000852.30] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00948.
# [000852.31] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.317.
# [000852.35] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 43.2 (reliable).
# [000852.35] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0134.
# [000855.05] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000855.07] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0144 > 0.01.
# [000855.09] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00609.
# [000855.16] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00918.
# [000855.17] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.302.
# [000855.23] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 42.4 (reliable).
# [000855.23] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0199.
# [000857.91] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000857.93] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.011 > 0.01.
# [000857.95] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00525.
# [000858.02] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0146.
# [000858.03] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.307.
# [000858.08] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 42.4 (reliable).
# [000858.08] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00121.
# [000860.79] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000860.81] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0117 > 0.01.
# [000860.83] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00498.
# [000860.90] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0125.
# [000860.91] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.29.
# [000860.96] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 42.4 (reliable).
# [000860.96] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00296.
# [000863.52] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000863.54] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0143 > 0.01.
# [000863.58] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00479.
# [000863.65] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00897.
# [000863.66] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.27.
# [000863.71] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 42.5 (reliable).
# [000863.71] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00257.
# [000866.27] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000866.29] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0125 > 0.01.
# [000866.31] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00538.
# [000866.38] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0127.
# [000866.39] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.263.
# [000866.44] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 42.8 (reliable).
# [000866.44] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00623.
# [000869.02] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000869.04] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.00804 < 0.01.
# [000869.05] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00541.
# [000869.13] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0175.
# [000869.14] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.259.
# [000869.18] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 42.9 (reliable).
# [000869.18] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00266.
# [000871.76] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000871.78] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0129 > 0.01.
# [000871.80] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00526.
# [000871.88] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0163.
# [000871.89] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.24.
# [000871.93] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 43.1 (reliable).
# [000871.93] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00374.
# [000874.53] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000874.54] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.00929 < 0.01.
# [000874.56] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00602.
# [000874.64] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0144.
# [000874.65] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.233.
# [000874.69] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 43.5 (reliable).
# [000874.69] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0109.
# [000877.23] [0/1] 08-14 17:25  EmceeSampler              INFO     Diagnostics:
# [000877.25] [0/1] 08-14 17:25  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0123 > 0.01.
# [000877.27] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00621.
# [000877.35] [0/1] 08-14 17:25  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.013.
# [000877.36] [0/1] 08-14 17:25  EmceeSampler              INFO     - max Geweke is 0.212.
# [000877.40] [0/1] 08-14 17:25  EmceeSampler              INFO     - max integrated autocorrelation time is 43.5 (reliable).
# [000877.41] [0/1] 08-14 17:25  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0025.
# [000880.14] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000880.16] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0148 > 0.01.
# [000880.18] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00715.
# [000880.26] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0128.
# [000880.27] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.192.
# [000880.32] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43.5 (reliable).
# [000880.32] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.000216.
# [000883.04] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000883.06] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.012 > 0.01.
# [000883.10] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00721.
# [000883.18] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0105.
# [000883.19] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.185.
# [000883.23] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43.3 (reliable).
# [000883.23] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00656.
# [000885.82] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000885.83] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0123 > 0.01.
# [000885.85] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00819.
# [000885.94] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0172.
# [000885.95] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.191.
# [000885.99] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 42.9 (reliable).
# [000886.00] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0102.
# [000888.70] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000888.72] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0148 > 0.01.
# [000888.73] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00751.
# [000888.82] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00997.
# [000888.83] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.204.
# [000888.87] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43 (reliable).
# [000888.87] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00332.
# [000891.45] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000891.47] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0155 > 0.01.
# [000891.49] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00783.
# [000891.57] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00883.
# [000891.58] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.207.
# [000891.63] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43.5 (reliable).
# [000891.63] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0173.
# [000894.32] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000894.34] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.015 > 0.01.
# [000894.36] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.0077.
# [000894.44] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0123.
# [000894.45] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.198.
# [000894.50] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43.8 (reliable).
# [000894.50] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00643.
# [000897.60] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000897.63] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0145 > 0.01.
# [000897.65] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00691.
# [000897.74] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0101.
# [000897.75] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.22.
# [000897.79] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43.2 (reliable).
# [000897.79] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0141.
# [000900.51] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000900.53] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0119 > 0.01.
# [000900.54] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00653.
# [000900.63] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00614.
# [000900.64] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.23.
# [000900.69] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43.4 (reliable).
# [000900.69] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00408.
# [000903.27] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000903.29] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0105 > 0.01.
# [000903.31] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00681.
# [000903.40] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00646.
# [000903.41] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.235.
# [000903.45] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43.6 (reliable).
# [000903.45] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00753.
# [000906.01] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000906.03] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0112 > 0.01.
# [000906.05] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00686.
# [000906.14] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00887.
# [000906.15] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.218.
# [000906.20] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43.5 (reliable).
# [000906.20] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00399.
# [000908.76] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000908.78] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.00909 < 0.01.
# [000908.80] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00585.
# [000908.89] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00812.
# [000908.90] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.215.
# [000908.95] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43 (reliable).
# [000908.95] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0106.
# [000911.53] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000911.55] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0109 > 0.01.
# [000911.57] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00546.
# [000911.66] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00845.
# [000911.67] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.22.
# [000911.72] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43.2 (reliable).
# [000911.72] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00798.
# [000914.28] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000914.30] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0147 > 0.01.
# [000914.32] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00493.
# [000914.41] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0107.
# [000914.42] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.212.
# [000914.47] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43.2 (reliable).
# [000914.47] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00147.
# [000917.42] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000917.44] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0144 > 0.01.
# [000917.46] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00468.
# [000917.56] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0117.
# [000917.56] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.204.
# [000917.61] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43.2 (reliable).
# [000917.61] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00166.
# [000920.18] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000920.21] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.012 > 0.01.
# [000920.22] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00357.
# [000920.32] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.0111.
# [000920.33] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.201.
# [000920.40] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 43.3 (reliable).
# [000920.40] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00576.
# [000922.99] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000923.02] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0122 > 0.01.
# [000923.04] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00369.
# [000923.13] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00909.
# [000923.14] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.197.
# [000923.19] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 42.8 (reliable).
# [000923.19] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.0103.
# [000925.75] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000925.77] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0141 > 0.01.
# [000925.80] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00391.
# [000925.90] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00837.
# [000925.90] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.195.
# [000925.95] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 42.8 (reliable).
# [000925.95] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00589.
# [000928.56] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000928.58] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0136 > 0.01.
# [000928.60] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00351.
# [000928.70] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00808.
# [000928.70] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.203.
# [000928.75] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 42.8 (reliable).
# [000928.75] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00135.
# [000931.31] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000931.33] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0122 > 0.01.
# [000931.35] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00324.
# [000931.46] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00699.
# [000931.46] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.206.
# [000931.51] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 42.9 (reliable).
# [000931.51] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00483.
# [000934.16] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000934.18] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0117 > 0.01.
# [000934.20] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00302.
# [000934.31] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00609.
# [000934.32] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.214.
# [000934.37] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 42.7 (reliable).
# [000934.37] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00509.
# [000937.06] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000937.09] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.0122 > 0.01.
# [000937.11] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00281.
# [000937.21] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00635.
# [000937.22] [0/1] 08-14 17:26  EmceeSampler              INFO     - max Geweke is 0.214.
# [000937.32] [0/1] 08-14 17:26  EmceeSampler              INFO     - max integrated autocorrelation time is 42.7 (reliable).
# [000937.32] [0/1] 08-14 17:26  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00506.
# [000940.01] [0/1] 08-14 17:26  EmceeSampler              INFO     Diagnostics:
# [000940.03] [0/1] 08-14 17:26  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.00932 < 0.01.
# [000940.05] [0/1] 08-14 17:26  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00218.
# [000940.19] [0/1] 08-14 17:27  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00833.
# [000940.21] [0/1] 08-14 17:27  EmceeSampler              INFO     - max Geweke is 0.222.
# [000940.41] [0/1] 08-14 17:27  EmceeSampler              INFO     - max integrated autocorrelation time is 42.8 (reliable).
# [000940.41] [0/1] 08-14 17:27  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00296.
# [000943.16] [0/1] 08-14 17:27  EmceeSampler              INFO     Diagnostics:
# [000943.18] [0/1] 08-14 17:27  EmceeSampler              INFO     - max eigen Gelman-Rubin - 1 is 0.00683 < 0.01.
# [000943.20] [0/1] 08-14 17:27  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 is 0.00176.
# [000943.31] [0/1] 08-14 17:27  EmceeSampler              INFO     - max diag Gelman-Rubin - 1 at 1.0 sigmas is 0.00587.
# [000943.32] [0/1] 08-14 17:27  EmceeSampler              INFO     - max Geweke is 0.235.
# [000943.40] [0/1] 08-14 17:27  EmceeSampler              INFO     - max integrated autocorrelation time is 42.5 (reliable).
# [000943.40] [0/1] 08-14 17:27  EmceeSampler              INFO     - max variation of integrated autocorrelation time is 0.00883.

# %%
chain = sampler.chains[0].remove_burnin(0.5)
print(chain.to_stats(tablefmt='pretty'))
plotting.plot_triangle(chain, markers={'Omega_m': cosmo.Omega0_m, 'A_s': cosmo.A_s, 'h': cosmo.h})
# Out:
# +---------+----------+----------+----------+---------+-------------------+---------------------+
# |         |  argmax  |   mean   |  median  |   std   |  quantile:1sigma  |   interval:1sigma   |
# +---------+----------+----------+----------+---------+-------------------+---------------------+
# | Omega_m |  0.3155  |  0.3154  |  0.3154  | 0.0011  |  -0.0011/+0.0011  |   -0.0011/+0.0011   |
# |   A_s   | 2.046e-9 | 2.045e-9 | 2.045e-9 | 1.1e-11 | -1.0e-11/+1.0e-11 | -10.0e-12/+1.06e-11 |
# |    h    |  0.6728  |  0.6730  |  0.6730  | 0.0021  |  -0.0020/+0.0019  |   -0.0020/+0.0019   |
# +---------+----------+----------+----------+---------+-------------------+---------------------+
# Removed no burn in
